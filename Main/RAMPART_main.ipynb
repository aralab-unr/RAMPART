# %%
#!/usr/bin/env python
# coding: utf-8

import sys
import os
from PP_environment.environment import Env
from scipy.stats import truncnorm
import pandas as pd
import numpy as np
import random
import pickle
import uuid
import time
import math
import os
import copy
from operator import add, sub, mul
from termcolor import colored
from scipy.optimize import fsolve
import matplotlib.pyplot as plt
import matplotlib.animation as FuncAnimation
from IPython import display
from IPython.display import HTML
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, LSTM, Input, Embedding, Flatten, Concatenate
from tensorflow.keras.optimizers import Adam
from numpy.random import randn
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.utils import plot_model

## starting main program
start = time.time()


gridHeightList = [int(sys.argv[1])]
gridWidthList = [int(sys.argv[1])]
noAgentList = [int(sys.argv[2])]
noObsList = [int(sys.argv[3])]
eList = [int(sys.argv[4])]
LoopVal = int(sys.argv[5]) # defines how many times the code will run
neighborWeightsList = [float(sys.argv[6])]
attackPercentage = [int(sys.argv[7])]
display = sys.argv[8]
sleep = float(sys.argv[9])
try:
    mode = sys.argv[10]
except:
    mode = 'random'
    
env_type=sys.argv[11].lower()

lossT = float(sys.argv[12])
epochB = int(sys.argv[13])
episodeL = int(sys.argv[14])
detectT = float(sys.argv[15])

if mode.lower()=='random':
    playModeList = {"Agent":'random', "Target":'static', "Obstacle":'random', "Freeway":'random'}
else:
    playModeList = {"Agent":'random', "Target":'static', "Obstacle":'static', "Freeway":'static'}
    
flag = 0 # flag = 0, neighbor zone enabled and flag = 1, neighbor zone disabled

noTarget = 1 # there is only one target
noFreeway = 1 # there is only one freeway/resting area
AttackerList = [random.sample(range(1,noAgentList[0]), math.ceil(noAgentList[0]*attackPercentage[0]/100))] # calculating attackers' list
print("Attackers: ", AttackerList)


fig, axs = plt.subplots((noAgentList[0])-len(AttackerList[0])+1,1, sharex=True)

 # reward and penalties
actionReward = 0
obsReward = -1.5
freewayReward = 0.5
emptycellReward = 0
hitwallReward = -0.5
goalReward = 10

min_v = obsReward+hitwallReward
max_v = goalReward+freewayReward+emptycellReward

# hyper-parameters
alpha = 0.1 # RL learning rate
varepsilon = 0.5 # privacy budget
degree = 10


### Laplace-based LDP mechanism
def Lap(randomlist, max_v, min_v, varepsilon, alpha):
    # print("actual value: ", randomlist)
    p_dataset = []
    b = (((max_v-min_v)*alpha)/varepsilon)
    for val in range(len(randomlist)):
        p_val = val + np.random.laplace(0, b)
        while ((p_val<min_v) or (p_val>max_v)):
            p_val = val + np.random.laplace(0, b)
        p_dataset.append(p_val)
    return p_dataset


### LDP-exploited attack mechanism
def attack(oldQAttacker, degree, min_v, max_v, varepsilon, alpha, adviseeQ):
    newQAttackerDegree =[]
    newQAttacker = []
    newQAttackerList = []
    b = ((max_v-min_v)*alpha)/varepsilon
    degreeVal = 0
    degreeFlag = True
    while degreeFlag==True:
        degreeVal += 1
        func = lambda k: ((2*b**2)/(k**2 - b**2)) - np.log(k**2) + np.log((k**2) - (b**2)) - degreeVal
        k_initial_guess = b+1
        p = fsolve(func, k_initial_guess)

        k1 = p[0]
        theta = 0
        miu_attacker = (((b**2)*(theta - (2*k1))) - (theta * (k1**2))) /((b**2) - (k1**2))

        for Q in oldQAttacker:
            noise = np.random.laplace(miu_attacker, b)
            AdvQ = Q + noise
            while ((AdvQ<min_v) or (AdvQ>max_v)):
                noise = np.random.laplace(miu_attacker, b)
                AdvQ = Q + noise
            newQAttackerDegree.append(AdvQ)
            
        if ((newQAttackerDegree[adviseeQ.index(max(adviseeQ))]<max(adviseeQ)) or (degreeVal>15)):
            degreeFlag = False
        else:
            pass
        item = newQAttackerDegree.copy()
        newQAttackerDegree = []
        
    print("Degree Val: ",degreeVal)
    return degreeVal, item


def GAN(n_states):
    n_states = n_states
    d_lossList= []
    g_lossList = []
    latent_dim = 10
    epochs = 100
    n_batch = 6

    # define the standalone discriminator model
    def define_discriminator(n_inputs=4):
        # State input
        state_input = Input(shape=(1,))
        state_embed = Embedding(n_states, 10)(state_input)
        state_embed = Flatten()(state_embed)

        # Q-values input
        q_values_input = Input(shape=(n_inputs,))

        # Concatenate state and q_values
        merged = Concatenate()([state_embed, q_values_input])

        # Hidden layers
        hidden1 = Dense(25, activation='relu')(merged)
        hidden2 = Dense(15, activation='relu')(hidden1)  # Updated hidden layer size

        # Output layer
        output = Dense(1, activation='sigmoid')(hidden2)

        model = Model([state_input, q_values_input], output)

        # compile model
        model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002, beta_1=0.5), metrics=['accuracy'])
        return model


    # define the standalone generator model
    def define_generator(latent_dim, n_outputs=4):
        # State input
        state_input = Input(shape=(1,))
        state_embed = Embedding(n_states, 10)(state_input)
        state_embed = Flatten()(state_embed)

        # Latent space input
        latent_input = Input(shape=(latent_dim,))

        # Concatenate state and latent input
        merged = Concatenate()([state_embed, latent_input])

        # Hidden layer
        hidden1 = Dense(25, activation='relu')(merged)  # Change hidden layer size to 25

        # Output layer
        output = Dense(n_outputs, activation='linear')(hidden1)

        model = Model([state_input, latent_input], output)

        model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.0002, beta_1=0.5), metrics=['mean_absolute_error'])

        return model


    def define_gan(generator, discriminator):
        # Get the generator input layers
        generator_state_input = generator.input[0]
        generator_latent_input = generator.input[1]

        # Generate fake samples
        generator_output = generator([generator_state_input, generator_latent_input])

        # Get the discriminator output from the generator
        discriminator_output = discriminator([generator_state_input, generator_output])

        # Combine the generator and discriminator into a single model
        model = Model([generator_state_input, generator_latent_input], discriminator_output)

        # Compile the model
        model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002, beta_1=0.5))

        return model
    
    discriminator = define_discriminator()
    # create the generator
    generator = define_generator(latent_dim)
    # create the gan
    gan_model = define_gan(generator, discriminator)
    
    generator.save('models/generator_model.h5')
    discriminator.save('models/discriminator_model.h5')
    gan_model.save('models/gan_model.h5')
    
    return generator, discriminator, gan_model, epochs, n_batch, n_states, d_lossList, g_lossList, latent_dim




def GAN_train(generator, discriminator, gan_model, latent_dim, n_epochs, n_batch, noq, n_states, d_lossList, g_lossList, epochB,  lossT):

    # use the generator to generate n fake examples, with class labels
    def generate_fake_samples(generator, latent_dim, half_batch, fake_states):
        # generate points in the latent space
        x_input = generate_latent_points(latent_dim, half_batch)
        # predict outputs
        X = generator.predict([np.array(fake_states), x_input], verbose=0)
        # create class labels
        y = np.zeros((half_batch, 1))
        return X, y
    

    # generate points in latent space as input for the generator
    def generate_latent_points(latent_dim, half_batch):
        # generate points in the latent space
        x_input = randn(latent_dim * half_batch)
        # reshape into a batch of inputs for the network
        x_input = x_input.reshape(half_batch, latent_dim)
        return x_input


    def train(g_model, d_model, gan_model, latent_dim, neighborsOldQ, lossT, n_epochs=epochB,  n_batch=6, n_eval=100):     
        for GAN_i in range(n_epochs):
            # prepare real samples
            population = list(set(nonEmptyState))
            real_states = random.sample(population, half_batch)

            real_q_values = np.concatenate([np.expand_dims(neighborsOldQ[state][np.random.randint(0, len(neighborsOldQ[state]))], axis=0) for state in real_states], axis=0)
            y_real = np.ones((half_batch, 1))

            # prepare fake examples using generator model
            fake_states = np.random.randint(0, n_states, half_batch)
            x_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch,fake_states)

            real_states = np.array(real_states)
            
            # update discriminator
            d_loss_real = d_model.train_on_batch([real_states, real_q_values], y_real)
            d_loss_fake = d_model.train_on_batch([fake_states, x_fake], y_fake)
            d_loss = 0.5 * np.add(d_loss_real[0], d_loss_fake[0])
            d_lossList.append(d_loss)

            # prepare points in latent space as input for the generator
            gan_states = np.random.randint(0, n_states, n_batch)
            x_gan = generate_latent_points(latent_dim, n_batch)

            # create inverted labels for the fake samples
            y_gan = np.ones((n_batch, 1))

            # update the generator via the discriminator's error
            g_loss = gan_model.train_on_batch([gan_states, x_gan], y_gan)
            g_lossList.append(g_loss)

            # evaluate the model every n_eval epochs
            if (GAN_i+1) % n_eval == 0:
                print(f"Eval step: {GAN_i+1}, [D loss: {d_loss}] [G loss: {g_loss}]")

                eval_state = random.sample(population, 1)
                real_data = neighborsOldQ[eval_state[0]]
                fake_states = np.array(eval_state)
                pred_data = generate_fake_samples(generator, latent_dim, 1,fake_states)[0]
            GANflag = 1
            if d_loss > lossT:
                print("GAN training stopped at epoch: "+str(GAN_i)+" since discriminator's loss exceeds the loss threshold!")
                break
            


        return GANflag, d_lossList, g_lossList
    
    neighborsOldQ = noq
    
    # train model
    GANflag, d_lossList, g_lossList = train(generator, discriminator, gan_model, latent_dim, neighborsOldQ, lossT, n_epochs, n_batch)
    return GANflag, d_lossList, g_lossList, generator, discriminator, latent_dim


def detect_anomalies(generator, discriminator, latent_dim, count, neighbor_data, state):
    test_state = np.array([state])
    #  use the generator to generate n fake examples, with class labels
    def generate_fake_samples(generator, latent_dim, count, fake_states):
        # generate points in the latent space
        x_input = generate_latent_points(latent_dim, count)
        # predict outputs
#         X = generator.predict([np.random.randint(0, n_states, n), x_input], verbose=0)
        X = generator.predict([np.array(fake_states), x_input], verbose=0)
        # create class labels
        y = np.zeros((count, 1))
        return X, y

    # generate points in latent space as input for the generator
    def generate_latent_points(latent_dim, count):
        # generate points in the latent space
        x_input = randn(latent_dim * count)
        # reshape into a batch of inputs for the network
        x_input = x_input.reshape(count, latent_dim)
        return x_input
    
    
    test_state = np.array([state])
    auth_neighbor = discriminator.predict([test_state, neighbor_data])
    print("neighbor_synthetic: ", auth_neighbor)
    
    return auth_neighbor


 # initializing lists for calculating and saving convergence values
diffAvg1 = []
diffAvg2 = []
diffAvg3 = []
diffAvg4 = []
diffAvg5 = []
diffAvg4_0 = []
n_states = gridHeightList[0]*gridWidthList[0]
noq = {i:[] for i in range(n_states)}
d_lossList= []
g_lossList = []
attack_neighborL = []
noAttack_neighborL = []
noqList = []
GAN_trainFlag = 0
GANtrainCount =0

discardedAdvice = 0
keptAdvice = 0


# Main Loop ############################################################
for CriteriaVal in range(len(gridWidthList)):
    print("##################### Criteria Value: "+str(CriteriaVal)+" #######################\n")
    Attacker = AttackerList[CriteriaVal]
    Behb_tot = [100000 for tk in range(noAgentList[CriteriaVal])] # advisee's budget for seeking advice during experience harvesting (EH)
    Besb_tot = [10000 for pk in range(noAgentList[CriteriaVal])] # advisors' budget for seeking advice during experience giving (EG)
    fileName = str(uuid.uuid4())[:5] # initializing unique filename for storing learning outcomes
    stepsListFinal = []
    stepAgentListFinal = []
    rewards_all_episodesFinal = []
    qtableListFinal = []
    diffAvg5 = []
    for countVal in range(LoopVal):
        gridWidth = gridWidthList[CriteriaVal]
        gridHeight = gridHeightList[CriteriaVal]
        playMode = playModeList
        noAgent = noAgentList[CriteriaVal]
        noObs = noObsList[CriteriaVal]
        neighborWeights = neighborWeightsList[CriteriaVal]

        ## initialize varaibles
        qtableList = []
        aPosList = []
        stateList = []
        rewardList = []
        doneList = []
        actionList = []
        nextStateList = []
        rewards_all_episodes = []
        visitCount = []

        ## Check if no of elements greater than the state space or not
        if (noAgent+noTarget+noObs+noFreeway)>= (gridHeight * gridWidth):
            print("Total number of elements (agents, targets, obstacles) exceeds grid position")
        else:
            # building environment
            env = Env(gridHeight, gridWidth, playMode, noTarget, noAgent, noObs, noFreeway)
            print('-------Initial Environment---------\n')
            print("\n")

        ## for each agent, initializing a Q-table with random Q-values
        for a in range(noAgent):
            qtableList.append(np.random.rand(env.stateCount, env.actionCount).tolist())
        a = 0
            
        for a in range(noAgent):
            noqList.append(noq)
        a = 0
        
        genList = []
        disList = []
        ganList = []
        epochList = []
        batchList = []
        stList = []
        genLossList = []
        disLossList = []
        latentList = []
        
        for a in range(noAgent):
            genList = [[]for a in range(noAgent)]
            disList = [[]for a in range(noAgent)]
            ganList = [[]for a in range(noAgent)]
            epochList = [[]for a in range(noAgent)]
            batchList = [[]for a in range(noAgent)]
            stList = [[]for a in range(noAgent)]
            genLossList = [[]for a in range(noAgent)]
            disLossList = [[]for a in range(noAgent)]
            latentList = [[]for a in range(noAgent)]
            GANtrainCountL = [[0]for a in range(noAgent)]
        a = 0
            
        
        ## for each agent, initializing GAN models
        for a in range(noAgent):
            generator, discriminator, gan_model, n_epochs, n_batch, n_states, d_lossList, g_lossList, latent_dim = GAN(n_states)
            genList[a]=[generator]
            disList[a]=[discriminator]
            ganList[a]=[gan_model]
            epochList[a]=[n_epochs]
            batchList[a]=[n_batch]
            stList[a]=[n_states]
            genLossList[a]=g_lossList
            disLossList[a]=d_lossList
            latentList[a]=[latent_dim]
            
            generator.save('models/generator_model_'+str(a)+'.h5')
            discriminator.save('models/discriminator_model_'+str(a)+'.h5')
            gan_model.save('models/gan_model_'+str(a)+'.h5')
        a = 0

        ## hyperparameters
        totalEpisode = eList[CriteriaVal]
        gamma = 0.8 # discount factor
        epsilon = 0.08 #0.08 #exploration-exploitation
        intEpsilon = epsilon
        decay = 0.1 # decay of exploration-exploitation over episode
        stepsList = []
        alpha = 0.1 #learning rate

        
        ## initialize visit count for each state
        for i in range(noAgent):
            visitCount.append([0 for xV in range((gridWidth*gridHeight))])
            
        ## initialize current experience harvesting budget (EHB) and current experience sharing budget (ESB)
        Behb = Behb_tot.copy()
        Besb = Besb_tot.copy()
          
        stepAgentList = [[] for xS in range(noAgent)]    
        degreeValFinal = []  
        
        
        
        ## TRAINING loop---------#####------------------#####---------
        for epNum in range(totalEpisode):
            GANtrainCount = all(all(value > episodeL for value in nested_list) for nested_list in GANtrainCountL)
            if GANtrainCount==False and GAN_trainFlag!=1:
                print("GAN episode count (for all AVs): ", GANtrainCountL, '\n')
                for a in range(noAgent):
                    # determine half the size of one batch, for updating the discriminator
                    half_batch = int(batchList[a][0] / 2)
                    # manually enumerate epochs
                    nonEmptyState = []
                    for state in range(0,stList[a][0]):
                        if ((len(noqList[a][state])!=0) and (state not in nonEmptyState)):
                            nonEmptyState.append(state)

                    if len(nonEmptyState)>=half_batch: 
                        print("\nEpisode "+str(epNum)+": Agent-"+str(a)+" | GAN train started")
                        GANflag, d_lossList, g_lossList, generator, discriminator, latent_dim = GAN_train(genList[a][0], disList[a][0],
                                                                                                              ganList[a][0], latentList[a][0],
                                                                                                              epochList[a][0], batchList[a][0],
                                                                                                              noqList[a], stList[a][0], disLossList[a],
                                                                                                              genLossList[a], epochB, lossT)

                        # Check if the last value of g_lossList is lower than the previous value
                        if len(g_lossList) > 1 and d_lossList[-1] > d_lossList[-2] and g_lossList[-1] < g_lossList[-2] and g_lossList[-1]!=-1:
                            # Save the models
                            generator.save('models/generator_model_'+str(a)+'.h5')
                            discriminator.save('models/discriminator_model_'+str(a)+'.h5')
                            gan_model.save('models/gan_model_'+str(a)+'.h5')
                        else:
                            # Load the previous models
                            generator = load_model('models/generator_model_'+str(a)+'.h5')
                            discriminator = load_model('models/discriminator_model_'+str(a)+'.h5')
                            gan_model = load_model('models/gan_model_'+str(a)+'.h5')

                        disLossList[a] = d_lossList
                        genLossList[a] = g_lossList
                        genList[a] = [generator]
                        disList[a] = [discriminator]
                        latentList[a] = [latent_dim]
                        print("Train phase complete!")
                        GANtrainCountL[a] = [GANtrainCountL[a][0]+1]
                    else:
                        continue
                a = 0
                    

            
            degreeValListEp =[[] for xD in range(noAgent)]
            print("epoch #", epNum+1, "/", totalEpisode)
            tPosList, aPosList, stateList, rewardList, doneList, oPosList, fPosList, courierNumber = env.reset(playMode, noTarget, noAgent, noObs,
                                                                       noFreeway, gridWidth, gridHeight, epNum, CriteriaVal,countVal,neighborWeights,totalEpisode,LoopVal)
            rewards_current_episode =[0 for xR in range(noAgent)]
            doneList = [[a,'False'] for xDl in range(noAgent)]
            
            # render environment at the begining of every episode
            print("\n--------------Episode: ", epNum+1, " started----------------\n")            
            steps = 0
            completedAgent = []
            stepAgent = [0 for xSa in range(noAgent)]
            
            # uncomment only one line from below three lines according to your preference
            while [0, 'True'] not in doneList: # ends when agent0 reaches goal
#             while any('False' in sl for sl in doneList): # ends when all agents reach goal
#             while not any('True' in sl for sl in doneList): # ends when any agent reaches goal

                actionList = []
                if steps>(gridWidth*100):
                    break # break out of the episode if number of steps is too large to reach the goal.
                else:
                    steps +=1
                    
                ## find out neighbors starts---------------------------------------------------
                neighborDict = env.neighbors(noAgent, aPosList, gridWidth, gridHeight, flag)  
                neighborPosList = []
                for a in range(noAgent):
                    neighborsPrint = []
                    indNeighbor = []
                    for player in neighborDict[a]:
                        if a != aPosList.index(player):
                            indNeighbor.append(aPosList.index(player))
                        uniqueIndNeighbor = [*set(indNeighbor)]
                    neighborPosList.append(uniqueIndNeighbor)
                    uniqueIndNeighbor = []
                a = 0

                ## find out neighbors ends---------------------------------------------------
                
                ## find which agents have completed
                completedAgent = [xC for xC, yC in enumerate(doneList) if yC[1]=='True']
                
                for a in range(noAgent):
                    if ((a in completedAgent) and (stepAgent[a]==0)):
                        stepAgent[a] = steps
                a = 0
                
                ## update visit count for this state and every agent
                for a in range(noAgent):
                    visitCount[a][stateList[a]] += 1
                a = 0
                
                # Experience harvesting (EH) and Experience Giving (EG) phase
                for a in range(noAgent):
                    ## calculate Pehc (experience harvesting confidence) based on visit count and budget. 
                    # If visit count is too high (i.e., >100000) or too low (<100) for any episode, set experience harvesting confidence to low (i.e., will not seek for advice)
                    if ((visitCount[a][stateList[a]]< 100) or (visitCount[a][stateList[a]]> 100000)):
                        Pehc = 0
                    else:
                        Pehc = (1/np.sqrt(visitCount[a][stateList[a]])) * (np.sqrt(Behb[a]/Behb_tot[a]))
                    
                    if ((Pehc > 0) and (Pehc < 0.1)) :
                        Behb[a] = Behb[a]-1
                        QNeighbor  = []
                        if a not in completedAgent:
                            neighborsOldQ = 0
                            neighborsOldQList = []
                            selfOldQ = qtableList[a][stateList[a]]
                            if neighborPosList[a] !=[]:  #if not empty list
                                for n in neighborPosList[a]:
                                    ## calculate Pesc (experience sharing confidence) based on visit count and budget
                                    if (visitCount[n][stateList[a]]> visitCount[a][stateList[a]]):
                                        Pesc = (1-(1/np.sqrt(visitCount[n][stateList[a]]))) * (np.sqrt(Besb[n]/Besb_tot[n]))
                                    else:
                                        Pesc = 0
                                    ## if experience sharing confidence is high, give advice
                                    if Pesc > 0:
                                        
                                        Besb[n] = Besb[n]-1
                                        
                                        # incorporating LDP
                                        noisyQ = Lap(qtableList[n][stateList[a]], max_v, min_v, varepsilon, alpha)
                                        neighborsOldQ = noisyQ

                                        #### Attacking (if any attacker presents)
                                        ## if the neighbor is an attacker, proceed for attack
                                        if ((n in Attacker) and GANtrainCount==True):
                                            GAN_trainFlag=1
                                            # if the agent himself is not an attacker, proceed for attack
                                            if a not in Attacker:
                                                oldQAttacker = qtableList[n][stateList[a]].copy()
                                                degreeVal, neighborsOldQ = attack(oldQAttacker, degree, min_v, max_v, varepsilon, alpha, selfOldQ)
                                                print(colored("Honest", 'green') +" Advisee, P"+str(a)+" is receiving"+
                                                      colored(" Malicious", 'red', attrs=['reverse'])+
                                                      " advice from malicious Advisor, P"+str(n)+" at step: "+str(steps))
                                                degreeValListEp[n].append(degreeVal)


                                    
                                                ## GAN anomaly detection for malicious data
                                                attack_neighbor = detect_anomalies(genList[a][0],
                                                                                 disList[a][0],
                                                                                 latentList[a][0],
                                                                                 1,
                                                                                 np.array([neighborsOldQ]),
                                                                                 stateList[a])

                                                if attack_neighbor<=detectT:
                                                    neighborsOldQ = noisyQ # discard the advice
                                                    discardedAdvice +=1
                                                else:
                                                    neighborsOldQ = neighborsOldQ # keep the advice
                                                    keptAdvice +=1

                                                attack_neighborL.append(attack_neighbor)

                                            # if the advisee is an attacker, send him the non-malicious advice
                                            else:
                                                print(colored("Malicious", 'red')+" Advisee, P"+str(a)+" is receiving"+
                                                      colored(" Benign", 'green', attrs=['reverse'])+
                                                      " advice from malicious Advisor, P"+str(n)+" at step: "+str(steps))
                                                neighborsOldQ = neighborsOldQ

                                            # saving all the neighbors advice (malicious+non-malicious) in a list
                                            noqList[a][stateList[a]].append(neighborsOldQ) #noq means neighbors old Q

                                        # if the neighbor is NOT an attacker, DO NOT proceed for attack
                                        else:
                                            neighborsOldQ = neighborsOldQ
                                            print("Advisee, P"+str(a)+" is receiving"+
                                                      colored(" Benign", 'green', attrs=['reverse'])+
                                                      " advice from Advisor, P"+str(n)+" at step: "+str(steps))
                                            
                                            if GANtrainCount==True:
                                              ## GAN anomaly detection for non-malicious data
                                                noAttack_neighbor = detect_anomalies(genList[a][0],
                                                                                     disList[a][0],
                                                                                     latentList[a][0],
                                                                                     1,
                                                                                     np.array([neighborsOldQ]),
                                                                                     stateList[a])
                                                if noAttack_neighbor<=detectT:
                                                    neighborsOldQ = noisyQ # discard the advice
                                                    discardedAdvice +=1
                                                else:
                                                    neighborsOldQ = neighborsOldQ # keep the advice
                                                    keptAdvice +=1

                                                noAttack_neighborL.append(noAttack_neighbor)

                                            # saving all the neighbors advice (non-malicious) in a list
                                            noqList[a][stateList[a]].append(neighborsOldQ)

                                        # saving all the neighbors advice (attack or non-attack) in a list
                                        neighborsOldQList.append(neighborsOldQ)
                                    
                                    ## if experience sharing confidence is low, DO NOT give advice
                                    else:
                                        neighborsOldQ = []
                                        neighborsOldQList.append(neighborsOldQ)
                                
                                # combining neighbors expereince
                                if any(neighborsOldQList):
                                    for action in range(4): # here 4 stands for four different actions
                                        elem = [item[action] for item in neighborsOldQList if item!=[]]
                                        
                                        # selecting the most appropiate advice
                                        QNeighbor.append(np.mean(elem))
                                            
                                    # Weighted expereince aggregation
                                    qtableList[a][stateList[a]] = [sum(xt) for xt in zip([op * neighborWeights for op in selfOldQ], 
                                                     [oq * (1-neighborWeights) for oq in QNeighbor])]
                                else:
                                    qtableList[a][stateList[a]] = selfOldQ
                  
                
                # 1. select best action
                if np.random.uniform() < epsilon:
                    for a in range(noAgent):
                        actionList.append(env.randomAction())
                else:
                    for a in range(noAgent):
                        actionList.append(qtableList[a][stateList[a]].index(max(qtableList[a][stateList[a]])))
                        
                soqList = []   
                for a in range(noAgent):
                    soq = copy.deepcopy(qtableList[a])  #soq means self old Q
                    soqList.append(soq)
                
                # 2. take the action and observe next state & reward
                nextStateList, rewardList, doneList, oPosList, courierNumber = env.step(actionList, doneList, noTarget, noAgent, noObs, noFreeway,
                                                               actionReward, obsReward, freewayReward, emptycellReward,
                                                               hitwallReward, completedAgent, goalReward)

                # 3. Calculate self Q-value
                for a in range(noAgent):
                    if a not in completedAgent:
                        qtableList[a][stateList[a]][actionList[a]] = ((qtableList[a][stateList[a]][actionList[a]] * (1 - alpha)) + (alpha * (rewardList[a] + gamma * max(qtableList[a][nextStateList[a]]))))
                        rewards_current_episode[a] += rewardList[a]
                        stateList[a] = nextStateList[a]
                    else:
                        qtableList[a][stateList[a]][actionList[a]] = qtableList[a][stateList[a]][actionList[a]]
                        rewards_current_episode[a] += rewardList[a]
                        stateList[a] = nextStateList[a]

                snqList = []
                for a in range(noAgent):
                    snq = copy.deepcopy(qtableList[a]) # snq means self new Q
                    snqList.append(snq)
                
                # calcuating \Delta Q for convergence analysis
                for p in range(len(soq)):
                    for q in range(len(soq[p])):
                        diff = abs(soqList[0][p][q] - snqList[0][p][q])
                        diffAvg1.append(diff)
                    diffAvg2.append(sum(diffAvg1)/len(diffAvg1))
                    diffAvg1 = []
                diffAvg3.append(sum(diffAvg2)/len(diffAvg2))
                diffAvg2 = []
                
            
            degreeValFinal.append(degreeValListEp)
            degreeValListEp=[]
            diffAvg4.append(sum(diffAvg3)/len(diffAvg3))
            diffAvg3 = []
            
            
            
            epsilon -= decay*epsilon # decaying exploration-exploitation probability for future episodes
            
            stepsList.append(steps)
            rewards_all_episodes.append(rewards_current_episode)
            print("Done in", steps, "steps".format(steps))
            time.sleep(sleep)
            
            color = ['red','cyan','black', 'green', 'magenta', 'orange', 'yellow', 
                     'red','cyan','black', 'green', 'magenta', 'orange', 'yellow',
                    'red','cyan','black', 'green', 'magenta', 'orange', 'yellow']
            stepAgent[stepAgent.index(0)]= steps
            axsCount = 0
            for a in range(noAgent):
                stepAgentList[a].append(stepAgent[a])
                if a not in Attacker:
                    axs[axsCount].plot(stepAgentList[a], marker='.', color=color[axsCount])
                    axs[axsCount].set_xticks([i for i in range(len(stepAgentList[a]))][-1:])
                    axs[axsCount].set_ylabel('P'+str(a))
                    axs[axsCount].set_ylim(0,500)
                    axs[axsCount].grid()
                    axsCount = axsCount+1
            axs[0].set_title("Attackers are: "+"P"+str(Attacker))
            axs[(noAgent-len(Attacker))].plot(stepsList, marker='x', color='blue')
            axs[(noAgent-len(Attacker))].set_xticks([i for i in range(len(stepsList))][-1:])
            axs[(noAgent-len(Attacker))].set_ylabel('All')
            axs[(noAgent-len(Attacker))].grid()
            axs[(noAgent-len(Attacker))].set_ylim(0,500)

        stepsListFinal.append(stepsList)
        stepsList = []
        rewards_all_episodesFinal.append(rewards_all_episodes)
        rewards_all_episodes = []
        qtableListFinal.append(qtableList)
        qtableList = []
        diffAvg5.append(diffAvg4)
        diffAvg4 = []
        diffAvg4_0 =[]
    
    
    end = time.time()
    total_time = end-start
    print("Total Time taken: ",total_time) 
    
env_type='low'

dvf = degreeValFinal
with open("./SG/"+str(env_type)+"/"+str(fileName)+"_RAMPART_DegreeVal", "wb") as Sd:   #Pickling
    pickle.dump(dvf, Sd)

sa = stepAgentList
with open("./SG/"+str(env_type)+"/"+str(fileName)+"_RAMPART_Step_AgentWise", "wb") as Spa:   #Pickling
    pickle.dump(sa, Spa)

s = stepsListFinal
with open("./SG/"+str(env_type)+"/"+str(fileName)+"_RAMPART_Step", "wb") as Sp:   #Pickling
    pickle.dump(s, Sp)

r = rewards_all_episodesFinal
with open("./Reward/"+str(env_type)+"/"+str(fileName)+"_RAMPART_Reward", "wb") as Rp:   #Pickling
    pickle.dump(r, Rp)

q = qtableListFinal
with open("./Qtable/"+str(env_type)+"/"+str(fileName)+"_RAMPART_Qtable", "wb") as Qp:   #Pickling
    pickle.dump(q, Qp)

c = diffAvg5
with open("./Convergence/"+str(env_type)+"/"+str(fileName)+"_RAMPARTconvergence", "wb") as Cp:   #Pickling
    pickle.dump(c, Cp)


t = total_time
with open("./TG/"+str(env_type)+"/"+str(fileName)+"_RAMPART_Time", "wb") as Tp:   #Pickling
    pickle.dump(t, Tp)   
    
l = disLossList
with open("./Loss/"+str(env_type)+"/"+str(fileName)+"_RAMPART_DisLoss", "wb") as Lp:   #Pickling
    pickle.dump(l, Lp)

l = genLossList
with open("./Loss/"+str(env_type)+"/"+str(fileName)+"_RAMPART_GenLoss", "wb") as Lp:   #Pickling
    pickle.dump(l, Lp)


nn =[]
for ix in range(0, len(noAttack_neighborL)):
    nn.append(noAttack_neighborL[ix][0])
    
atn =[]
for iy in range(0, len(attack_neighborL)):
    atn.append(attack_neighborL[iy][0])
    
AS = nn
with open("./AS/"+str(env_type)+"/"+str(fileName)+"_RAMPART_AS_nn", "wb") as ASp:   #Pickling
    pickle.dump(AS, ASp)
    
AS = atn
with open("./AS/"+str(env_type)+"/"+str(fileName)+"_RAMPART_AS_atn", "wb") as ASp:   #Pickling
    pickle.dump(AS, ASp)
    



with open("./OutputFile/RAMPART.txt", "a") as myfile:
    myfile.write("FileName: "+str(fileName)+" : RAMPART, Time taken: "+str(total_time)+"\n | gridWidth: "+str(gridWidth)+" | gridHeight: "+str(gridHeight)+
                " | playMode: "+str(playMode)+" | noTarget: "+str(noTarget)+" | noAgent: "+str(noAgent)+
                " | noObs: "+str(noObs)+" | noFreeway: "+str(noFreeway)+
                " | neighborWeights: "+str(neighborWeights)+" | totalEpisode: "+str(totalEpisode)+" | gamma: "+str(gamma)+
                " | epsilon: "+str(intEpsilon)+" | decay: "+str(decay)+" | alpha: "+str(alpha)+
                " | obsReward: "+str(obsReward)+" | freewayReward: "+str(freewayReward)+" | emptycellReward: "+str(emptycellReward)+
                " | hitwallReward: "+str(hitwallReward)+" | Attacker: "+str(Attacker)+" | Notes: "+str("LDP+Attack+RAMPART")+"\n\n\n")
# Out:
# Attackers:  [[]]
# ##################### Criteria Value: 0 #######################
#
# -------Initial Environment---------
#
#
#
# epoch # 1 / 2000
#
# --------------Episode:  1  started----------------
#
# Done in 272 steps
# epoch # 2 / 2000
#
# --------------Episode:  2  started----------------
#
# Done in 256 steps
# epoch # 3 / 2000
#
# --------------Episode:  3  started----------------
#
# Done in 24 steps
# epoch # 4 / 2000
#
# --------------Episode:  4  started----------------
#
# Done in 12 steps
# epoch # 5 / 2000
#
# --------------Episode:  5  started----------------
#
# Done in 10 steps
# epoch # 6 / 2000
#
# --------------Episode:  6  started----------------
#
# Done in 118 steps
# epoch # 7 / 2000
#
# --------------Episode:  7  started----------------
#
# Done in 7 steps
# epoch # 8 / 2000
#
# --------------Episode:  8  started----------------
#
# Done in 3 steps
# epoch # 9 / 2000
#
# --------------Episode:  9  started----------------
#
# Done in 5 steps
# epoch # 10 / 2000
#
# --------------Episode:  10  started----------------
#
# Done in 17 steps
# epoch # 11 / 2000
#
# --------------Episode:  11  started----------------
#
# Done in 11 steps
# epoch # 12 / 2000
#
# --------------Episode:  12  started----------------
#
# Done in 4 steps
# epoch # 13 / 2000
#
# --------------Episode:  13  started----------------
#
# Done in 12 steps
# epoch # 14 / 2000
#
# --------------Episode:  14  started----------------
#
# Done in 13 steps
# epoch # 15 / 2000
#
# --------------Episode:  15  started----------------
#
# Done in 6 steps
# epoch # 16 / 2000
#
# --------------Episode:  16  started----------------
#
# Done in 13 steps
# epoch # 17 / 2000
#
# --------------Episode:  17  started----------------
#
# Done in 4 steps
# epoch # 18 / 2000
#
# --------------Episode:  18  started----------------
#
# Done in 9 steps
# epoch # 19 / 2000
#
# --------------Episode:  19  started----------------
#
# Done in 6 steps
# epoch # 20 / 2000
#
# --------------Episode:  20  started----------------
#
# Done in 7 steps
# epoch # 21 / 2000
#
# --------------Episode:  21  started----------------
#
# Done in 6 steps
# epoch # 22 / 2000
#
# --------------Episode:  22  started----------------
#
# Done in 6 steps
# epoch # 23 / 2000
#
# --------------Episode:  23  started----------------
#
# Done in 8 steps
# epoch # 24 / 2000
#
# --------------Episode:  24  started----------------
#
# Done in 10 steps
# epoch # 25 / 2000
#
# --------------Episode:  25  started----------------
#
# Done in 11 steps
# epoch # 26 / 2000
#
# --------------Episode:  26  started----------------
#
# Done in 13 steps
# epoch # 27 / 2000
#
# --------------Episode:  27  started----------------
#
# Done in 3 steps
# epoch # 28 / 2000
#
# --------------Episode:  28  started----------------
#
# Done in 13 steps
# epoch # 29 / 2000
#
# --------------Episode:  29  started----------------
#
# Done in 7 steps
# epoch # 30 / 2000
#
# --------------Episode:  30  started----------------
#
# Done in 5 steps
# epoch # 31 / 2000
#
# --------------Episode:  31  started----------------
#
# Done in 5 steps
# epoch # 32 / 2000
#
# --------------Episode:  32  started----------------
#
# Done in 4 steps
# epoch # 33 / 2000
#
# --------------Episode:  33  started----------------
#
# Done in 9 steps
# epoch # 34 / 2000
#
# --------------Episode:  34  started----------------
#
# Done in 12 steps
# epoch # 35 / 2000
#
# --------------Episode:  35  started----------------
#
# Done in 5 steps
# epoch # 36 / 2000
#
# --------------Episode:  36  started----------------
#
# Done in 9 steps
# epoch # 37 / 2000
#
# --------------Episode:  37  started----------------
#
# Done in 8 steps
# epoch # 38 / 2000
#
# --------------Episode:  38  started----------------
#
# Done in 7 steps
# epoch # 39 / 2000
#
# --------------Episode:  39  started----------------
#
# Done in 6 steps
# epoch # 40 / 2000
#
# --------------Episode:  40  started----------------
#
# Done in 4 steps
# epoch # 41 / 2000
#
# --------------Episode:  41  started----------------
#
# Done in 4 steps
# epoch # 42 / 2000
#
# --------------Episode:  42  started----------------
#
# Done in 3 steps
# epoch # 43 / 2000
#
# --------------Episode:  43  started----------------
#
# Done in 8 steps
# epoch # 44 / 2000
#
# --------------Episode:  44  started----------------
#
# Done in 6 steps
# epoch # 45 / 2000
#
# --------------Episode:  45  started----------------
#
# Done in 3 steps
# epoch # 46 / 2000
#
# --------------Episode:  46  started----------------
#
# Done in 5 steps
# epoch # 47 / 2000
#
# --------------Episode:  47  started----------------
#
# Done in 6 steps
# epoch # 48 / 2000
#
# --------------Episode:  48  started----------------
#
# Done in 9 steps
# epoch # 49 / 2000
#
# --------------Episode:  49  started----------------
#
# Done in 7 steps
# epoch # 50 / 2000
#
# --------------Episode:  50  started----------------
#
# Done in 6 steps
# epoch # 51 / 2000
#
# --------------Episode:  51  started----------------
#
# Done in 7 steps
# epoch # 52 / 2000
#
# --------------Episode:  52  started----------------
#
# Done in 7 steps
# epoch # 53 / 2000
#
# --------------Episode:  53  started----------------
#
# Done in 10 steps
# epoch # 54 / 2000
#
# --------------Episode:  54  started----------------
#
# Done in 8 steps
# epoch # 55 / 2000
#
# --------------Episode:  55  started----------------
#
# Done in 6 steps
# epoch # 56 / 2000
#
# --------------Episode:  56  started----------------
#
# Done in 7 steps
# epoch # 57 / 2000
#
# --------------Episode:  57  started----------------
#
# Done in 4 steps
# epoch # 58 / 2000
#
# --------------Episode:  58  started----------------
#
# Done in 11 steps
# epoch # 59 / 2000
#
# --------------Episode:  59  started----------------
#
# Done in 7 steps
# epoch # 60 / 2000
#
# --------------Episode:  60  started----------------
#
# Done in 4 steps
# epoch # 61 / 2000
#
# --------------Episode:  61  started----------------
#
# Done in 6 steps
# epoch # 62 / 2000
#
# --------------Episode:  62  started----------------
#
# Done in 4 steps
# epoch # 63 / 2000
#
# --------------Episode:  63  started----------------
#
# Done in 5 steps
# epoch # 64 / 2000
#
# --------------Episode:  64  started----------------
#
# Done in 4 steps
# epoch # 65 / 2000
#
# --------------Episode:  65  started----------------
#
# Done in 6 steps
# epoch # 66 / 2000
#
# --------------Episode:  66  started----------------
#
# Done in 6 steps
# epoch # 67 / 2000
#
# --------------Episode:  67  started----------------
#
# Done in 7 steps
# epoch # 68 / 2000
#
# --------------Episode:  68  started----------------
#
# Done in 7 steps
# epoch # 69 / 2000
#
# --------------Episode:  69  started----------------
#
# Done in 5 steps
# epoch # 70 / 2000
#
# --------------Episode:  70  started----------------
#
# Done in 5 steps
# epoch # 71 / 2000
#
# --------------Episode:  71  started----------------
#
# Done in 8 steps
# epoch # 72 / 2000
#
# --------------Episode:  72  started----------------
#
# Done in 4 steps
# epoch # 73 / 2000
#
# --------------Episode:  73  started----------------
#
# Done in 5 steps
# epoch # 74 / 2000
#
# --------------Episode:  74  started----------------
#
# Done in 6 steps
# epoch # 75 / 2000
#
# --------------Episode:  75  started----------------
#
# Done in 6 steps
# epoch # 76 / 2000
#
# --------------Episode:  76  started----------------
#
# Done in 5 steps
# epoch # 77 / 2000
#
# --------------Episode:  77  started----------------
#
# Done in 4 steps
# epoch # 78 / 2000
#
# --------------Episode:  78  started----------------
#
# Done in 5 steps
# epoch # 79 / 2000
#
# --------------Episode:  79  started----------------
#
# Done in 5 steps
# epoch # 80 / 2000
#
# --------------Episode:  80  started----------------
#
# Done in 6 steps
# epoch # 81 / 2000
#
# --------------Episode:  81  started----------------
#
# Done in 5 steps
# epoch # 82 / 2000
#
# --------------Episode:  82  started----------------
#
# Done in 7 steps
# epoch # 83 / 2000
#
# --------------Episode:  83  started----------------
#
# Done in 10 steps
# epoch # 84 / 2000
#
# --------------Episode:  84  started----------------
#
# Done in 11 steps
# epoch # 85 / 2000
#
# --------------Episode:  85  started----------------
#
# Done in 5 steps
# epoch # 86 / 2000
#
# --------------Episode:  86  started----------------
#
# Done in 8 steps
# epoch # 87 / 2000
#
# --------------Episode:  87  started----------------
#
# Done in 7 steps
# epoch # 88 / 2000
#
# --------------Episode:  88  started----------------
#
# Done in 3 steps
# epoch # 89 / 2000
#
# --------------Episode:  89  started----------------
#
# Done in 5 steps
# epoch # 90 / 2000
#
# --------------Episode:  90  started----------------
#
# Done in 7 steps
# epoch # 91 / 2000
#
# --------------Episode:  91  started----------------
#
# Done in 4 steps
# epoch # 92 / 2000
#
# --------------Episode:  92  started----------------
#
# Done in 6 steps
# epoch # 93 / 2000
#
# --------------Episode:  93  started----------------
#
# Done in 5 steps
# epoch # 94 / 2000
#
# --------------Episode:  94  started----------------
#
# Done in 8 steps
# epoch # 95 / 2000
#
# --------------Episode:  95  started----------------
#
# Done in 4 steps
# epoch # 96 / 2000
#
# --------------Episode:  96  started----------------
#
# Done in 8 steps
# epoch # 97 / 2000
#
# --------------Episode:  97  started----------------
#
# Done in 7 steps
# epoch # 98 / 2000
#
# --------------Episode:  98  started----------------
#
# Done in 5 steps
# epoch # 99 / 2000
#
# --------------Episode:  99  started----------------
#
# Done in 7 steps
# epoch # 100 / 2000
#
# --------------Episode:  100  started----------------
#
# Done in 8 steps
# epoch # 101 / 2000
#
# --------------Episode:  101  started----------------
#
# Done in 7 steps
# epoch # 102 / 2000
#
# --------------Episode:  102  started----------------
#
# Done in 6 steps
# epoch # 103 / 2000
#
# --------------Episode:  103  started----------------
#
# Done in 3 steps
# epoch # 104 / 2000
#
# --------------Episode:  104  started----------------
#
# Done in 5 steps
# epoch # 105 / 2000
#
# --------------Episode:  105  started----------------
#
# Done in 5 steps
# epoch # 106 / 2000
#
# --------------Episode:  106  started----------------
#
# Done in 4 steps
# epoch # 107 / 2000
#
# --------------Episode:  107  started----------------
#
# Done in 9 steps
# epoch # 108 / 2000
#
# --------------Episode:  108  started----------------
#
# Done in 6 steps
# epoch # 109 / 2000
#
# --------------Episode:  109  started----------------
#
# Done in 5 steps
# epoch # 110 / 2000
#
# --------------Episode:  110  started----------------
#
# Done in 4 steps
# epoch # 111 / 2000
#
# --------------Episode:  111  started----------------
#
# Done in 6 steps
# epoch # 112 / 2000
#
# --------------Episode:  112  started----------------
#
# Done in 7 steps
# epoch # 113 / 2000
#
# --------------Episode:  113  started----------------
#
# Done in 7 steps
# epoch # 114 / 2000
#
# --------------Episode:  114  started----------------
#
# Done in 5 steps
# epoch # 115 / 2000
#
# --------------Episode:  115  started----------------
#
# Done in 5 steps
# epoch # 116 / 2000
#
# --------------Episode:  116  started----------------
#
# Done in 5 steps
# epoch # 117 / 2000
#
# --------------Episode:  117  started----------------
#
# Done in 8 steps
# epoch # 118 / 2000
#
# --------------Episode:  118  started----------------
#
# Done in 6 steps
# epoch # 119 / 2000
#
# --------------Episode:  119  started----------------
#
# Done in 5 steps
# epoch # 120 / 2000
#
# --------------Episode:  120  started----------------
#
# Done in 5 steps
# epoch # 121 / 2000
#
# --------------Episode:  121  started----------------
#
# Done in 4 steps
# epoch # 122 / 2000
#
# --------------Episode:  122  started----------------
#
# Done in 7 steps
# epoch # 123 / 2000
#
# --------------Episode:  123  started----------------
#
# Done in 8 steps
# epoch # 124 / 2000
#
# --------------Episode:  124  started----------------
#
# Done in 5 steps
# epoch # 125 / 2000
#
# --------------Episode:  125  started----------------
#
# Done in 4 steps
# epoch # 126 / 2000
#
# --------------Episode:  126  started----------------
#
# Done in 8 steps
# epoch # 127 / 2000
#
# --------------Episode:  127  started----------------
#
# Done in 9 steps
# epoch # 128 / 2000
#
# --------------Episode:  128  started----------------
#
# Done in 7 steps
# epoch # 129 / 2000
#
# --------------Episode:  129  started----------------
#
# Done in 6 steps
# epoch # 130 / 2000
#
# --------------Episode:  130  started----------------
#
# Done in 3 steps
# epoch # 131 / 2000
#
# --------------Episode:  131  started----------------
#
# Done in 6 steps
# epoch # 132 / 2000
#
# --------------Episode:  132  started----------------
#
# Done in 5 steps
# epoch # 133 / 2000
#
# --------------Episode:  133  started----------------
#
# Done in 5 steps
# epoch # 134 / 2000
#
# --------------Episode:  134  started----------------
#
# Done in 6 steps
# epoch # 135 / 2000
#
# --------------Episode:  135  started----------------
#
# Done in 6 steps
# epoch # 136 / 2000
#
# --------------Episode:  136  started----------------
#
# Done in 4 steps
# epoch # 137 / 2000
#
# --------------Episode:  137  started----------------
#
# Done in 7 steps
# epoch # 138 / 2000
#
# --------------Episode:  138  started----------------
#
# Done in 7 steps
# epoch # 139 / 2000
#
# --------------Episode:  139  started----------------
#
# Done in 7 steps
# epoch # 140 / 2000
#
# --------------Episode:  140  started----------------
#
# Done in 7 steps
# epoch # 141 / 2000
#
# --------------Episode:  141  started----------------
#
# Done in 7 steps
# epoch # 142 / 2000
#
# --------------Episode:  142  started----------------
#
# Done in 3 steps
# epoch # 143 / 2000
#
# --------------Episode:  143  started----------------
#
# Done in 5 steps
# epoch # 144 / 2000
#
# --------------Episode:  144  started----------------
#
# Done in 9 steps
# epoch # 145 / 2000
#
# --------------Episode:  145  started----------------
#
# Done in 6 steps
# epoch # 146 / 2000
#
# --------------Episode:  146  started----------------
#
# Done in 7 steps
# epoch # 147 / 2000
#
# --------------Episode:  147  started----------------
#
# Done in 7 steps
# epoch # 148 / 2000
#
# --------------Episode:  148  started----------------
#
# Done in 5 steps
# epoch # 149 / 2000
#
# --------------Episode:  149  started----------------
#
# Done in 3 steps
# epoch # 150 / 2000
#
# --------------Episode:  150  started----------------
#
# Done in 8 steps
# epoch # 151 / 2000
#
# --------------Episode:  151  started----------------
#
# Done in 7 steps
# epoch # 152 / 2000
#
# --------------Episode:  152  started----------------
#
# Done in 4 steps
# epoch # 153 / 2000
#
# --------------Episode:  153  started----------------
#
# Done in 9 steps
# epoch # 154 / 2000
#
# --------------Episode:  154  started----------------
#
# Done in 5 steps
# epoch # 155 / 2000
#
# --------------Episode:  155  started----------------
#
# Done in 6 steps
# epoch # 156 / 2000
#
# --------------Episode:  156  started----------------
#
# Done in 8 steps
# epoch # 157 / 2000
#
# --------------Episode:  157  started----------------
#
# Done in 6 steps
# epoch # 158 / 2000
#
# --------------Episode:  158  started----------------
#
# Done in 9 steps
# epoch # 159 / 2000
#
# --------------Episode:  159  started----------------
#
# Done in 8 steps
# epoch # 160 / 2000
#
# --------------Episode:  160  started----------------
#
# Done in 4 steps
# epoch # 161 / 2000
#
# --------------Episode:  161  started----------------
#
# Done in 5 steps
# epoch # 162 / 2000
#
# --------------Episode:  162  started----------------
#
# Done in 5 steps
# epoch # 163 / 2000
#
# --------------Episode:  163  started----------------
#
# Done in 8 steps
# epoch # 164 / 2000
#
# --------------Episode:  164  started----------------
#
# Done in 6 steps
# epoch # 165 / 2000
#
# --------------Episode:  165  started----------------
#
# Done in 8 steps
# epoch # 166 / 2000
#
# --------------Episode:  166  started----------------
#
# Done in 7 steps
# epoch # 167 / 2000
#
# --------------Episode:  167  started----------------
#
# Done in 4 steps
# epoch # 168 / 2000
#
# --------------Episode:  168  started----------------
#
# Done in 8 steps
# epoch # 169 / 2000
#
# --------------Episode:  169  started----------------
#
# Done in 6 steps
# epoch # 170 / 2000
#
# --------------Episode:  170  started----------------
#
# Done in 7 steps
# epoch # 171 / 2000
#
# --------------Episode:  171  started----------------
#
# Done in 3 steps
# epoch # 172 / 2000
#
# --------------Episode:  172  started----------------
#
# Done in 5 steps
# epoch # 173 / 2000
#
# --------------Episode:  173  started----------------
#
# Done in 6 steps
# epoch # 174 / 2000
#
# --------------Episode:  174  started----------------
#
# Done in 4 steps
# epoch # 175 / 2000
#
# --------------Episode:  175  started----------------
#
# Done in 4 steps
# epoch # 176 / 2000
#
# --------------Episode:  176  started----------------
#
# Done in 8 steps
# epoch # 177 / 2000
#
# --------------Episode:  177  started----------------
#
# Done in 8 steps
# epoch # 178 / 2000
#
# --------------Episode:  178  started----------------
#
# Done in 6 steps
# epoch # 179 / 2000
#
# --------------Episode:  179  started----------------
#
# Done in 8 steps
# epoch # 180 / 2000
#
# --------------Episode:  180  started----------------
#
# Done in 4 steps
# epoch # 181 / 2000
#
# --------------Episode:  181  started----------------
#
# Done in 5 steps
# epoch # 182 / 2000
#
# --------------Episode:  182  started----------------
#
# Done in 6 steps
# epoch # 183 / 2000
#
# --------------Episode:  183  started----------------
#
# Done in 8 steps
# epoch # 184 / 2000
#
# --------------Episode:  184  started----------------
#
# Done in 6 steps
# epoch # 185 / 2000
#
# --------------Episode:  185  started----------------
#
# Done in 6 steps
# epoch # 186 / 2000
#
# --------------Episode:  186  started----------------
#
# Done in 6 steps
# epoch # 187 / 2000
#
# --------------Episode:  187  started----------------
#
# Done in 5 steps
# epoch # 188 / 2000
#
# --------------Episode:  188  started----------------
#
# Done in 9 steps
# epoch # 189 / 2000
#
# --------------Episode:  189  started----------------
#
# Done in 5 steps
# epoch # 190 / 2000
#
# --------------Episode:  190  started----------------
#
# Done in 5 steps
# epoch # 191 / 2000
#
# --------------Episode:  191  started----------------
#
# Done in 5 steps
# epoch # 192 / 2000
#
# --------------Episode:  192  started----------------
#
# Done in 5 steps
# epoch # 193 / 2000
#
# --------------Episode:  193  started----------------
#
# Done in 6 steps
# epoch # 194 / 2000
#
# --------------Episode:  194  started----------------
#
# Done in 6 steps
# epoch # 195 / 2000
#
# --------------Episode:  195  started----------------
#
# Done in 5 steps
# epoch # 196 / 2000
#
# --------------Episode:  196  started----------------
#
# Done in 6 steps
# epoch # 197 / 2000
#
# --------------Episode:  197  started----------------
#
# Done in 3 steps
# epoch # 198 / 2000
#
# --------------Episode:  198  started----------------
#
# Done in 7 steps
# epoch # 199 / 2000
#
# --------------Episode:  199  started----------------
#
# Done in 8 steps
# epoch # 200 / 2000
#
# --------------Episode:  200  started----------------
#
# Done in 5 steps
# epoch # 201 / 2000
#
# --------------Episode:  201  started----------------
#
# Done in 5 steps
# epoch # 202 / 2000
#
# --------------Episode:  202  started----------------
#
# Done in 5 steps
# epoch # 203 / 2000
#
# --------------Episode:  203  started----------------
#
# Done in 5 steps
# epoch # 204 / 2000
#
# --------------Episode:  204  started----------------
#
# Done in 5 steps
# epoch # 205 / 2000
#
# --------------Episode:  205  started----------------
#
# Done in 7 steps
# epoch # 206 / 2000
#
# --------------Episode:  206  started----------------
#
# Done in 5 steps
# epoch # 207 / 2000
#
# --------------Episode:  207  started----------------
#
# Done in 4 steps
# epoch # 208 / 2000
#
# --------------Episode:  208  started----------------
#
# Done in 6 steps
# epoch # 209 / 2000
#
# --------------Episode:  209  started----------------
#
# Done in 5 steps
# epoch # 210 / 2000
#
# --------------Episode:  210  started----------------
#
# Done in 4 steps
# epoch # 211 / 2000
#
# --------------Episode:  211  started----------------
#
# Done in 9 steps
# epoch # 212 / 2000
#
# --------------Episode:  212  started----------------
#
# Done in 5 steps
# epoch # 213 / 2000
#
# --------------Episode:  213  started----------------
#
# Done in 3 steps
# epoch # 214 / 2000
#
# --------------Episode:  214  started----------------
#
# Done in 3 steps
# epoch # 215 / 2000
#
# --------------Episode:  215  started----------------
#
# Done in 5 steps
# epoch # 216 / 2000
#
# --------------Episode:  216  started----------------
#
# Done in 9 steps
# epoch # 217 / 2000
#
# --------------Episode:  217  started----------------
#
# Done in 7 steps
# epoch # 218 / 2000
#
# --------------Episode:  218  started----------------
#
# Done in 4 steps
# epoch # 219 / 2000
#
# --------------Episode:  219  started----------------
#
# Done in 5 steps
# epoch # 220 / 2000
#
# --------------Episode:  220  started----------------
#
# Done in 4 steps
# epoch # 221 / 2000
#
# --------------Episode:  221  started----------------
#
# Done in 4 steps
# epoch # 222 / 2000
#
# --------------Episode:  222  started----------------
#
# Done in 5 steps
# epoch # 223 / 2000
#
# --------------Episode:  223  started----------------
#
# Done in 8 steps
# epoch # 224 / 2000
#
# --------------Episode:  224  started----------------
#
# Done in 4 steps
# epoch # 225 / 2000
#
# --------------Episode:  225  started----------------
#
# Done in 4 steps
# epoch # 226 / 2000
#
# --------------Episode:  226  started----------------
#
# Done in 4 steps
# epoch # 227 / 2000
#
# --------------Episode:  227  started----------------
#
# Done in 6 steps
# epoch # 228 / 2000
#
# --------------Episode:  228  started----------------
#
# Done in 9 steps
# epoch # 229 / 2000
#
# --------------Episode:  229  started----------------
#
# Done in 8 steps
# epoch # 230 / 2000
#
# --------------Episode:  230  started----------------
#
# Done in 5 steps
# epoch # 231 / 2000
#
# --------------Episode:  231  started----------------
#
# Done in 6 steps
# epoch # 232 / 2000
#
# --------------Episode:  232  started----------------
#
# Done in 7 steps
# epoch # 233 / 2000
#
# --------------Episode:  233  started----------------
#
# Done in 4 steps
# epoch # 234 / 2000
#
# --------------Episode:  234  started----------------
#
# Done in 4 steps
# epoch # 235 / 2000
#
# --------------Episode:  235  started----------------
#
# Done in 4 steps
# epoch # 236 / 2000
#
# --------------Episode:  236  started----------------
#
# Done in 6 steps
# epoch # 237 / 2000
#
# --------------Episode:  237  started----------------
#
# Done in 6 steps
# epoch # 238 / 2000
#
# --------------Episode:  238  started----------------
#
# Done in 4 steps
# epoch # 239 / 2000
#
# --------------Episode:  239  started----------------
#
# Done in 7 steps
# epoch # 240 / 2000
#
# --------------Episode:  240  started----------------
#
# Done in 6 steps
# epoch # 241 / 2000
#
# --------------Episode:  241  started----------------
#
# Done in 5 steps
# epoch # 242 / 2000
#
# --------------Episode:  242  started----------------
#
# Done in 5 steps
# epoch # 243 / 2000
#
# --------------Episode:  243  started----------------
#
# Done in 7 steps
# epoch # 244 / 2000
#
# --------------Episode:  244  started----------------
#
# Done in 8 steps
# epoch # 245 / 2000
#
# --------------Episode:  245  started----------------
#
# Done in 7 steps
# epoch # 246 / 2000
#
# --------------Episode:  246  started----------------
#
# Done in 6 steps
# epoch # 247 / 2000
#
# --------------Episode:  247  started----------------
#
# Done in 5 steps
# epoch # 248 / 2000
#
# --------------Episode:  248  started----------------
#
# Done in 4 steps
# epoch # 249 / 2000
#
# --------------Episode:  249  started----------------
#
# Done in 6 steps
# epoch # 250 / 2000
#
# --------------Episode:  250  started----------------
#
# Done in 6 steps
# epoch # 251 / 2000
#
# --------------Episode:  251  started----------------
#
# Done in 5 steps
# epoch # 252 / 2000
#
# --------------Episode:  252  started----------------
#
# Done in 8 steps
# epoch # 253 / 2000
#
# --------------Episode:  253  started----------------
#
# Done in 6 steps
# epoch # 254 / 2000
#
# --------------Episode:  254  started----------------
#
# Done in 7 steps
# epoch # 255 / 2000
#
# --------------Episode:  255  started----------------
#
# Done in 4 steps
# epoch # 256 / 2000
#
# --------------Episode:  256  started----------------
#
# Done in 3 steps
# epoch # 257 / 2000
#
# --------------Episode:  257  started----------------
#
# Done in 7 steps
# epoch # 258 / 2000
#
# --------------Episode:  258  started----------------
#
# Done in 3 steps
# epoch # 259 / 2000
#
# --------------Episode:  259  started----------------
#
# Done in 6 steps
# epoch # 260 / 2000
#
# --------------Episode:  260  started----------------
#
# Done in 5 steps
# epoch # 261 / 2000
#
# --------------Episode:  261  started----------------
#
# Done in 5 steps
# epoch # 262 / 2000
#
# --------------Episode:  262  started----------------
#
# Done in 7 steps
# epoch # 263 / 2000
#
# --------------Episode:  263  started----------------
#
# Done in 5 steps
# epoch # 264 / 2000
#
# --------------Episode:  264  started----------------
#
# Done in 9 steps
# epoch # 265 / 2000
#
# --------------Episode:  265  started----------------
#
# Done in 5 steps
# epoch # 266 / 2000
#
# --------------Episode:  266  started----------------
#
# Done in 4 steps
# epoch # 267 / 2000
#
# --------------Episode:  267  started----------------
#
# Done in 8 steps
# epoch # 268 / 2000
#
# --------------Episode:  268  started----------------
#
# Done in 4 steps
# epoch # 269 / 2000
#
# --------------Episode:  269  started----------------
#
# Done in 4 steps
# epoch # 270 / 2000
#
# --------------Episode:  270  started----------------
#
# Done in 5 steps
# epoch # 271 / 2000
#
# --------------Episode:  271  started----------------
#
# Done in 7 steps
# epoch # 272 / 2000
#
# --------------Episode:  272  started----------------
#
# Done in 5 steps
# epoch # 273 / 2000
#
# --------------Episode:  273  started----------------
#
# Done in 7 steps
# epoch # 274 / 2000
#
# --------------Episode:  274  started----------------
#
# Done in 3 steps
# epoch # 275 / 2000
#
# --------------Episode:  275  started----------------
#
# Done in 9 steps
# epoch # 276 / 2000
#
# --------------Episode:  276  started----------------
#
# Done in 5 steps
# epoch # 277 / 2000
#
# --------------Episode:  277  started----------------
#
# Done in 3 steps
# epoch # 278 / 2000
#
# --------------Episode:  278  started----------------
#
# Done in 8 steps
# epoch # 279 / 2000
#
# --------------Episode:  279  started----------------
#
# Done in 7 steps
# epoch # 280 / 2000
#
# --------------Episode:  280  started----------------
#
# Done in 8 steps
# epoch # 281 / 2000
#
# --------------Episode:  281  started----------------
#
# Done in 8 steps
# epoch # 282 / 2000
#
# --------------Episode:  282  started----------------
#
# Done in 4 steps
# epoch # 283 / 2000
#
# --------------Episode:  283  started----------------
#
# Done in 7 steps
# epoch # 284 / 2000
#
# --------------Episode:  284  started----------------
#
# Done in 4 steps
# epoch # 285 / 2000
#
# --------------Episode:  285  started----------------
#
# Done in 5 steps
# epoch # 286 / 2000
#
# --------------Episode:  286  started----------------
#
# Done in 6 steps
# epoch # 287 / 2000
#
# --------------Episode:  287  started----------------
#
# Done in 4 steps
# epoch # 288 / 2000
#
# --------------Episode:  288  started----------------
#
# Done in 8 steps
# epoch # 289 / 2000
#
# --------------Episode:  289  started----------------
#
# Done in 6 steps
# epoch # 290 / 2000
#
# --------------Episode:  290  started----------------
#
# Done in 7 steps
# epoch # 291 / 2000
#
# --------------Episode:  291  started----------------
#
# Done in 8 steps
# epoch # 292 / 2000
#
# --------------Episode:  292  started----------------
#
# Done in 9 steps
# epoch # 293 / 2000
#
# --------------Episode:  293  started----------------
#
# Done in 5 steps
# epoch # 294 / 2000
#
# --------------Episode:  294  started----------------
#
# Done in 8 steps
# epoch # 295 / 2000
#
# --------------Episode:  295  started----------------
#
# Done in 6 steps
# epoch # 296 / 2000
#
# --------------Episode:  296  started----------------
#
# Done in 6 steps
# epoch # 297 / 2000
#
# --------------Episode:  297  started----------------
#
# Done in 5 steps
# epoch # 298 / 2000
#
# --------------Episode:  298  started----------------
#
# Done in 8 steps
# epoch # 299 / 2000
#
# --------------Episode:  299  started----------------
#
# Done in 5 steps
# epoch # 300 / 2000
#
# --------------Episode:  300  started----------------
#
# Done in 6 steps
# epoch # 301 / 2000
#
# --------------Episode:  301  started----------------
#
# Done in 4 steps
# epoch # 302 / 2000
#
# --------------Episode:  302  started----------------
#
# Done in 8 steps
# epoch # 303 / 2000
#
# --------------Episode:  303  started----------------
#
# Done in 5 steps
# epoch # 304 / 2000
#
# --------------Episode:  304  started----------------
#
# Done in 5 steps
# epoch # 305 / 2000
#
# --------------Episode:  305  started----------------
#
# Done in 5 steps
# epoch # 306 / 2000
#
# --------------Episode:  306  started----------------
#
# Done in 6 steps
# epoch # 307 / 2000
#
# --------------Episode:  307  started----------------
#
# Done in 5 steps
# epoch # 308 / 2000
#
# --------------Episode:  308  started----------------
#
# Done in 7 steps
# epoch # 309 / 2000
#
# --------------Episode:  309  started----------------
#
# Done in 9 steps
# epoch # 310 / 2000
#
# --------------Episode:  310  started----------------
#
# Done in 5 steps
# epoch # 311 / 2000
#
# --------------Episode:  311  started----------------
#
# Done in 8 steps
# epoch # 312 / 2000
#
# --------------Episode:  312  started----------------
#
# Done in 6 steps
# epoch # 313 / 2000
#
# --------------Episode:  313  started----------------
#
# Done in 8 steps
# epoch # 314 / 2000
#
# --------------Episode:  314  started----------------
#
# Done in 5 steps
# epoch # 315 / 2000
#
# --------------Episode:  315  started----------------
#
# Done in 7 steps
# epoch # 316 / 2000
#
# --------------Episode:  316  started----------------
#
# Done in 5 steps
# epoch # 317 / 2000
#
# --------------Episode:  317  started----------------
#
# Done in 7 steps
# epoch # 318 / 2000
#
# --------------Episode:  318  started----------------
#
# Done in 5 steps
# epoch # 319 / 2000
#
# --------------Episode:  319  started----------------
#
# Done in 7 steps
# epoch # 320 / 2000
#
# --------------Episode:  320  started----------------
#
# Done in 7 steps
# epoch # 321 / 2000
#
# --------------Episode:  321  started----------------
#
# Done in 5 steps
# epoch # 322 / 2000
#
# --------------Episode:  322  started----------------
#
# Done in 7 steps
# epoch # 323 / 2000
#
# --------------Episode:  323  started----------------
#
# Done in 4 steps
# epoch # 324 / 2000
#
# --------------Episode:  324  started----------------
#
# Done in 4 steps
# epoch # 325 / 2000
#
# --------------Episode:  325  started----------------
#
# Done in 7 steps
# epoch # 326 / 2000
#
# --------------Episode:  326  started----------------
#
# Done in 3 steps
# epoch # 327 / 2000
#
# --------------Episode:  327  started----------------
#
# Done in 7 steps
# epoch # 328 / 2000
#
# --------------Episode:  328  started----------------
#
# Done in 3 steps
# epoch # 329 / 2000
#
# --------------Episode:  329  started----------------
#
# Done in 5 steps
# epoch # 330 / 2000
#
# --------------Episode:  330  started----------------
#
# Done in 4 steps
# epoch # 331 / 2000
#
# --------------Episode:  331  started----------------
#
# Done in 8 steps
# epoch # 332 / 2000
#
# --------------Episode:  332  started----------------
#
# Done in 8 steps
# epoch # 333 / 2000
#
# --------------Episode:  333  started----------------
#
# Done in 5 steps
# epoch # 334 / 2000
#
# --------------Episode:  334  started----------------
#
# Done in 5 steps
# epoch # 335 / 2000
#
# --------------Episode:  335  started----------------
#
# Done in 4 steps
# epoch # 336 / 2000
#
# --------------Episode:  336  started----------------
#
# Done in 6 steps
# epoch # 337 / 2000
#
# --------------Episode:  337  started----------------
#
# Done in 6 steps
# epoch # 338 / 2000
#
# --------------Episode:  338  started----------------
#
# Done in 8 steps
# epoch # 339 / 2000
#
# --------------Episode:  339  started----------------
#
# Done in 4 steps
# epoch # 340 / 2000
#
# --------------Episode:  340  started----------------
#
# Done in 7 steps
# epoch # 341 / 2000
#
# --------------Episode:  341  started----------------
#
# Done in 4 steps
# epoch # 342 / 2000
#
# --------------Episode:  342  started----------------
#
# Done in 7 steps
# epoch # 343 / 2000
#
# --------------Episode:  343  started----------------
#
# Done in 5 steps
# epoch # 344 / 2000
#
# --------------Episode:  344  started----------------
#
# Done in 4 steps
# epoch # 345 / 2000
#
# --------------Episode:  345  started----------------
#
# Done in 7 steps
# epoch # 346 / 2000
#
# --------------Episode:  346  started----------------
#
# Done in 4 steps
# epoch # 347 / 2000
#
# --------------Episode:  347  started----------------
#
# Done in 9 steps
# epoch # 348 / 2000
#
# --------------Episode:  348  started----------------
#
# Done in 6 steps
# epoch # 349 / 2000
#
# --------------Episode:  349  started----------------
#
# Done in 6 steps
# epoch # 350 / 2000
#
# --------------Episode:  350  started----------------
#
# Done in 5 steps
# epoch # 351 / 2000
#
# --------------Episode:  351  started----------------
#
# Done in 4 steps
# epoch # 352 / 2000
#
# --------------Episode:  352  started----------------
#
# Done in 5 steps
# epoch # 353 / 2000
#
# --------------Episode:  353  started----------------
#
# Done in 4 steps
# epoch # 354 / 2000
#
# --------------Episode:  354  started----------------
#
# Done in 5 steps
# epoch # 355 / 2000
#
# --------------Episode:  355  started----------------
#
# Done in 8 steps
# epoch # 356 / 2000
#
# --------------Episode:  356  started----------------
#
# Done in 3 steps
# epoch # 357 / 2000
#
# --------------Episode:  357  started----------------
#
# Done in 6 steps
# epoch # 358 / 2000
#
# --------------Episode:  358  started----------------
#
# Done in 8 steps
# epoch # 359 / 2000
#
# --------------Episode:  359  started----------------
#
# Done in 8 steps
# epoch # 360 / 2000
#
# --------------Episode:  360  started----------------
#
# Done in 7 steps
# epoch # 361 / 2000
#
# --------------Episode:  361  started----------------
#
# Done in 4 steps
# epoch # 362 / 2000
#
# --------------Episode:  362  started----------------
#
# Done in 6 steps
# epoch # 363 / 2000
#
# --------------Episode:  363  started----------------
#
# Done in 8 steps
# epoch # 364 / 2000
#
# --------------Episode:  364  started----------------
#
# Done in 7 steps
# epoch # 365 / 2000
#
# --------------Episode:  365  started----------------
#
# Done in 3 steps
# epoch # 366 / 2000
#
# --------------Episode:  366  started----------------
#
# Done in 5 steps
# epoch # 367 / 2000
#
# --------------Episode:  367  started----------------
#
# Done in 7 steps
# epoch # 368 / 2000
#
# --------------Episode:  368  started----------------
#
# Done in 5 steps
# epoch # 369 / 2000
#
# --------------Episode:  369  started----------------
#
# Done in 5 steps
# epoch # 370 / 2000
#
# --------------Episode:  370  started----------------
#
# Done in 4 steps
# epoch # 371 / 2000
#
# --------------Episode:  371  started----------------
#
# Done in 5 steps
# epoch # 372 / 2000
#
# --------------Episode:  372  started----------------
#
# Done in 8 steps
# epoch # 373 / 2000
#
# --------------Episode:  373  started----------------
#
# Done in 3 steps
# epoch # 374 / 2000
#
# --------------Episode:  374  started----------------
#
# Done in 4 steps
# epoch # 375 / 2000
#
# --------------Episode:  375  started----------------
#
# Done in 4 steps
# epoch # 376 / 2000
#
# --------------Episode:  376  started----------------
#
# Done in 5 steps
# epoch # 377 / 2000
#
# --------------Episode:  377  started----------------
#
# Done in 5 steps
# epoch # 378 / 2000
#
# --------------Episode:  378  started----------------
#
# Done in 6 steps
# epoch # 379 / 2000
#
# --------------Episode:  379  started----------------
#
# Done in 6 steps
# epoch # 380 / 2000
#
# --------------Episode:  380  started----------------
#
# Done in 6 steps
# epoch # 381 / 2000
#
# --------------Episode:  381  started----------------
#
# Done in 5 steps
# epoch # 382 / 2000
#
# --------------Episode:  382  started----------------
#
# Done in 4 steps
# epoch # 383 / 2000
#
# --------------Episode:  383  started----------------
#
# Done in 6 steps
# epoch # 384 / 2000
#
# --------------Episode:  384  started----------------
#
# Done in 3 steps
# epoch # 385 / 2000
#
# --------------Episode:  385  started----------------
#
# Done in 5 steps
# epoch # 386 / 2000
#
# --------------Episode:  386  started----------------
#
# Done in 9 steps
# epoch # 387 / 2000
#
# --------------Episode:  387  started----------------
#
# Done in 5 steps
# epoch # 388 / 2000
#
# --------------Episode:  388  started----------------
#
# Done in 5 steps
# epoch # 389 / 2000
#
# --------------Episode:  389  started----------------
#
# Done in 8 steps
# epoch # 390 / 2000
#
# --------------Episode:  390  started----------------
#
# Done in 4 steps
# epoch # 391 / 2000
#
# --------------Episode:  391  started----------------
#
# Done in 6 steps
# epoch # 392 / 2000
#
# --------------Episode:  392  started----------------
#
# Done in 5 steps
# epoch # 393 / 2000
#
# --------------Episode:  393  started----------------
#
# Done in 7 steps
# epoch # 394 / 2000
#
# --------------Episode:  394  started----------------
#
# Done in 4 steps
# epoch # 395 / 2000
#
# --------------Episode:  395  started----------------
#
# Done in 3 steps
# epoch # 396 / 2000
#
# --------------Episode:  396  started----------------
#
# Done in 8 steps
# epoch # 397 / 2000
#
# --------------Episode:  397  started----------------
#
# Done in 7 steps
# epoch # 398 / 2000
#
# --------------Episode:  398  started----------------
#
# Done in 4 steps
# epoch # 399 / 2000
#
# --------------Episode:  399  started----------------
#
# Done in 4 steps
# epoch # 400 / 2000
#
# --------------Episode:  400  started----------------
#
# Done in 5 steps
# epoch # 401 / 2000
#
# --------------Episode:  401  started----------------
#
# Done in 3 steps
# epoch # 402 / 2000
#
# --------------Episode:  402  started----------------
#
# Done in 5 steps
# epoch # 403 / 2000
#
# --------------Episode:  403  started----------------
#
# Done in 5 steps
# epoch # 404 / 2000
#
# --------------Episode:  404  started----------------
#
# Done in 6 steps
# epoch # 405 / 2000
#
# --------------Episode:  405  started----------------
#
# Done in 8 steps
# epoch # 406 / 2000
#
# --------------Episode:  406  started----------------
#
# Done in 4 steps
# epoch # 407 / 2000
#
# --------------Episode:  407  started----------------
#
# Done in 6 steps
# epoch # 408 / 2000
#
# --------------Episode:  408  started----------------
#
# Done in 3 steps
# epoch # 409 / 2000
#
# --------------Episode:  409  started----------------
#
# Done in 5 steps
# epoch # 410 / 2000
#
# --------------Episode:  410  started----------------
#
# Done in 8 steps
# epoch # 411 / 2000
#
# --------------Episode:  411  started----------------
#
# Done in 8 steps
# epoch # 412 / 2000
#
# --------------Episode:  412  started----------------
#
# Done in 4 steps
# epoch # 413 / 2000
#
# --------------Episode:  413  started----------------
#
# Done in 8 steps
# epoch # 414 / 2000
#
# --------------Episode:  414  started----------------
#
# Done in 3 steps
# epoch # 415 / 2000
#
# --------------Episode:  415  started----------------
#
# Done in 5 steps
# epoch # 416 / 2000
#
# --------------Episode:  416  started----------------
#
# Done in 5 steps
# epoch # 417 / 2000
#
# --------------Episode:  417  started----------------
#
# Done in 5 steps
# epoch # 418 / 2000
#
# --------------Episode:  418  started----------------
#
# Done in 4 steps
# epoch # 419 / 2000
#
# --------------Episode:  419  started----------------
#
# Done in 4 steps
# epoch # 420 / 2000
#
# --------------Episode:  420  started----------------
#
# Done in 7 steps
# epoch # 421 / 2000
#
# --------------Episode:  421  started----------------
#
# Done in 9 steps
# epoch # 422 / 2000
#
# --------------Episode:  422  started----------------
#
# Done in 4 steps
# epoch # 423 / 2000
#
# --------------Episode:  423  started----------------
#
# Done in 3 steps
# epoch # 424 / 2000
#
# --------------Episode:  424  started----------------
#
# Done in 3 steps
# epoch # 425 / 2000
#
# --------------Episode:  425  started----------------
#
# Done in 4 steps
# epoch # 426 / 2000
#
# --------------Episode:  426  started----------------
#
# Done in 7 steps
# epoch # 427 / 2000
#
# --------------Episode:  427  started----------------
#
# Done in 9 steps
# epoch # 428 / 2000
#
# --------------Episode:  428  started----------------
#
# Done in 7 steps
# epoch # 429 / 2000
#
# --------------Episode:  429  started----------------
#
# Done in 5 steps
# epoch # 430 / 2000
#
# --------------Episode:  430  started----------------
#
# Done in 9 steps
# epoch # 431 / 2000
#
# --------------Episode:  431  started----------------
#
# Done in 6 steps
# epoch # 432 / 2000
#
# --------------Episode:  432  started----------------
#
# Done in 5 steps
# epoch # 433 / 2000
#
# --------------Episode:  433  started----------------
#
# Done in 5 steps
# epoch # 434 / 2000
#
# --------------Episode:  434  started----------------
#
# Done in 6 steps
# epoch # 435 / 2000
#
# --------------Episode:  435  started----------------
#
# Done in 8 steps
# epoch # 436 / 2000
#
# --------------Episode:  436  started----------------
#
# Done in 6 steps
# epoch # 437 / 2000
#
# --------------Episode:  437  started----------------
#
# Done in 4 steps
# epoch # 438 / 2000
#
# --------------Episode:  438  started----------------
#
# Done in 7 steps
# epoch # 439 / 2000
#
# --------------Episode:  439  started----------------
#
# Done in 8 steps
# epoch # 440 / 2000
#
# --------------Episode:  440  started----------------
#
# Done in 6 steps
# epoch # 441 / 2000
#
# --------------Episode:  441  started----------------
#
# Done in 4 steps
# epoch # 442 / 2000
#
# --------------Episode:  442  started----------------
#
# Done in 5 steps
# epoch # 443 / 2000
#
# --------------Episode:  443  started----------------
#
# Done in 8 steps
# epoch # 444 / 2000
#
# --------------Episode:  444  started----------------
#
# Done in 4 steps
# epoch # 445 / 2000
#
# --------------Episode:  445  started----------------
#
# Done in 4 steps
# epoch # 446 / 2000
#
# --------------Episode:  446  started----------------
#
# Done in 5 steps
# epoch # 447 / 2000
#
# --------------Episode:  447  started----------------
#
# Done in 3 steps
# epoch # 448 / 2000
#
# --------------Episode:  448  started----------------
#
# Done in 6 steps
# epoch # 449 / 2000
#
# --------------Episode:  449  started----------------
#
# Done in 6 steps
# epoch # 450 / 2000
#
# --------------Episode:  450  started----------------
#
# Done in 4 steps
# epoch # 451 / 2000
#
# --------------Episode:  451  started----------------
#
# Done in 5 steps
# epoch # 452 / 2000
#
# --------------Episode:  452  started----------------
#
# Done in 6 steps
# epoch # 453 / 2000
#
# --------------Episode:  453  started----------------
#
# Done in 4 steps
# epoch # 454 / 2000
#
# --------------Episode:  454  started----------------
#
# Done in 6 steps
# epoch # 455 / 2000
#
# --------------Episode:  455  started----------------
#
# Done in 7 steps
# epoch # 456 / 2000
#
# --------------Episode:  456  started----------------
#
# Done in 5 steps
# epoch # 457 / 2000
#
# --------------Episode:  457  started----------------
#
# Done in 4 steps
# epoch # 458 / 2000
#
# --------------Episode:  458  started----------------
#
# Done in 5 steps
# epoch # 459 / 2000
#
# --------------Episode:  459  started----------------
#
# Done in 7 steps
# epoch # 460 / 2000
#
# --------------Episode:  460  started----------------
#
# Done in 9 steps
# epoch # 461 / 2000
#
# --------------Episode:  461  started----------------
#
# Done in 4 steps
# epoch # 462 / 2000
#
# --------------Episode:  462  started----------------
#
# Done in 9 steps
# epoch # 463 / 2000
#
# --------------Episode:  463  started----------------
#
# Done in 3 steps
# epoch # 464 / 2000
#
# --------------Episode:  464  started----------------
#
# Done in 8 steps
# epoch # 465 / 2000
#
# --------------Episode:  465  started----------------
#
# Done in 4 steps
# epoch # 466 / 2000
#
# --------------Episode:  466  started----------------
#
# Done in 8 steps
# epoch # 467 / 2000
#
# --------------Episode:  467  started----------------
#
# Done in 5 steps
# epoch # 468 / 2000
#
# --------------Episode:  468  started----------------
#
# Done in 8 steps
# epoch # 469 / 2000
#
# --------------Episode:  469  started----------------
#
# Done in 7 steps
# epoch # 470 / 2000
#
# --------------Episode:  470  started----------------
#
# Done in 8 steps
# epoch # 471 / 2000
#
# --------------Episode:  471  started----------------
#
# Done in 5 steps
# epoch # 472 / 2000
#
# --------------Episode:  472  started----------------
#
# Done in 5 steps
# epoch # 473 / 2000
#
# --------------Episode:  473  started----------------
#
# Done in 7 steps
# epoch # 474 / 2000
#
# --------------Episode:  474  started----------------
#
# Done in 6 steps
# epoch # 475 / 2000
#
# --------------Episode:  475  started----------------
#
# Done in 8 steps
# epoch # 476 / 2000
#
# --------------Episode:  476  started----------------
#
# Done in 4 steps
# epoch # 477 / 2000
#
# --------------Episode:  477  started----------------
#
# Done in 6 steps
# epoch # 478 / 2000
#
# --------------Episode:  478  started----------------
#
# Done in 4 steps
# epoch # 479 / 2000
#
# --------------Episode:  479  started----------------
#
# Done in 7 steps
# epoch # 480 / 2000
#
# --------------Episode:  480  started----------------
#
# Done in 5 steps
# epoch # 481 / 2000
#
# --------------Episode:  481  started----------------
#
# Done in 7 steps
# epoch # 482 / 2000
#
# --------------Episode:  482  started----------------
#
# Done in 5 steps
# epoch # 483 / 2000
#
# --------------Episode:  483  started----------------
#
# Done in 8 steps
# epoch # 484 / 2000
#
# --------------Episode:  484  started----------------
#
# Done in 5 steps
# epoch # 485 / 2000
#
# --------------Episode:  485  started----------------
#
# Done in 3 steps
# epoch # 486 / 2000
#
# --------------Episode:  486  started----------------
#
# Done in 7 steps
# epoch # 487 / 2000
#
# --------------Episode:  487  started----------------
#
# Done in 6 steps
# epoch # 488 / 2000
#
# --------------Episode:  488  started----------------
#
# Done in 5 steps
# epoch # 489 / 2000
#
# --------------Episode:  489  started----------------
#
# Done in 5 steps
# epoch # 490 / 2000
#
# --------------Episode:  490  started----------------
#
# Done in 5 steps
# epoch # 491 / 2000
#
# --------------Episode:  491  started----------------
#
# Done in 4 steps
# epoch # 492 / 2000
#
# --------------Episode:  492  started----------------
#
# Done in 6 steps
# epoch # 493 / 2000
#
# --------------Episode:  493  started----------------
#
# Done in 5 steps
# epoch # 494 / 2000
#
# --------------Episode:  494  started----------------
#
# Done in 9 steps
# epoch # 495 / 2000
#
# --------------Episode:  495  started----------------
#
# Done in 4 steps
# epoch # 496 / 2000
#
# --------------Episode:  496  started----------------
#
# Done in 5 steps
# epoch # 497 / 2000
#
# --------------Episode:  497  started----------------
#
# Done in 5 steps
# epoch # 498 / 2000
#
# --------------Episode:  498  started----------------
#
# Done in 6 steps
# epoch # 499 / 2000
#
# --------------Episode:  499  started----------------
#
# Done in 4 steps
# epoch # 500 / 2000
#
# --------------Episode:  500  started----------------
#
# Done in 7 steps
# epoch # 501 / 2000
#
# --------------Episode:  501  started----------------
#
# Done in 8 steps
# epoch # 502 / 2000
#
# --------------Episode:  502  started----------------
#
# Done in 5 steps
# epoch # 503 / 2000
#
# --------------Episode:  503  started----------------
#
# Done in 5 steps
# epoch # 504 / 2000
#
# --------------Episode:  504  started----------------
#
# Done in 6 steps
# epoch # 505 / 2000
#
# --------------Episode:  505  started----------------
#
# Done in 8 steps
# epoch # 506 / 2000
#
# --------------Episode:  506  started----------------
#
# Done in 6 steps
# epoch # 507 / 2000
#
# --------------Episode:  507  started----------------
#
# Done in 3 steps
# epoch # 508 / 2000
#
# --------------Episode:  508  started----------------
#
# Done in 5 steps
# epoch # 509 / 2000
#
# --------------Episode:  509  started----------------
#
# Done in 6 steps
# epoch # 510 / 2000
#
# --------------Episode:  510  started----------------
#
# Done in 8 steps
# epoch # 511 / 2000
#
# --------------Episode:  511  started----------------
#
# Done in 8 steps
# epoch # 512 / 2000
#
# --------------Episode:  512  started----------------
#
# Done in 5 steps
# epoch # 513 / 2000
#
# --------------Episode:  513  started----------------
#
# Done in 8 steps
# epoch # 514 / 2000
#
# --------------Episode:  514  started----------------
#
# Done in 4 steps
# epoch # 515 / 2000
#
# --------------Episode:  515  started----------------
#
# Done in 8 steps
# epoch # 516 / 2000
#
# --------------Episode:  516  started----------------
#
# Done in 7 steps
# epoch # 517 / 2000
#
# --------------Episode:  517  started----------------
#
# Done in 3 steps
# epoch # 518 / 2000
#
# --------------Episode:  518  started----------------
#
# Done in 4 steps
# epoch # 519 / 2000
#
# --------------Episode:  519  started----------------
#
# Done in 7 steps
# epoch # 520 / 2000
#
# --------------Episode:  520  started----------------
#
# Done in 6 steps
# epoch # 521 / 2000
#
# --------------Episode:  521  started----------------
#
# Done in 6 steps
# epoch # 522 / 2000
#
# --------------Episode:  522  started----------------
#
# Done in 4 steps
# epoch # 523 / 2000
#
# --------------Episode:  523  started----------------
#
# Done in 3 steps
# epoch # 524 / 2000
#
# --------------Episode:  524  started----------------
#
# Done in 9 steps
# epoch # 525 / 2000
#
# --------------Episode:  525  started----------------
#
# Done in 6 steps
# epoch # 526 / 2000
#
# --------------Episode:  526  started----------------
#
# Done in 5 steps
# epoch # 527 / 2000
#
# --------------Episode:  527  started----------------
#
# Done in 5 steps
# epoch # 528 / 2000
#
# --------------Episode:  528  started----------------
#
# Done in 9 steps
# epoch # 529 / 2000
#
# --------------Episode:  529  started----------------
#
# Done in 4 steps
# epoch # 530 / 2000
#
# --------------Episode:  530  started----------------
#
# Done in 5 steps
# epoch # 531 / 2000
#
# --------------Episode:  531  started----------------
#
# Done in 5 steps
# epoch # 532 / 2000
#
# --------------Episode:  532  started----------------
#
# Done in 5 steps
# epoch # 533 / 2000
#
# --------------Episode:  533  started----------------
#
# Done in 4 steps
# epoch # 534 / 2000
#
# --------------Episode:  534  started----------------
#
# Done in 5 steps
# ...
#
# Done in 4 steps
# epoch # 1828 / 2000
#
# --------------Episode:  1828  started----------------
#
# Done in 6 steps
# epoch # 1829 / 2000
#
# --------------Episode:  1829  started----------------
#
# Done in 5 steps
# epoch # 1830 / 2000
#
# --------------Episode:  1830  started----------------
#
# Done in 4 steps
# epoch # 1831 / 2000
#
# --------------Episode:  1831  started----------------
#
# Done in 2 steps
# epoch # 1832 / 2000
#
# --------------Episode:  1832  started----------------
#
# Done in 5 steps
# epoch # 1833 / 2000
#
# --------------Episode:  1833  started----------------
#
# Done in 3 steps
# epoch # 1834 / 2000
#
# --------------Episode:  1834  started----------------
#
# Done in 3 steps
# epoch # 1835 / 2000
#
# --------------Episode:  1835  started----------------
#
# Done in 3 steps
# epoch # 1836 / 2000
#
# --------------Episode:  1836  started----------------
#
# Done in 5 steps
# epoch # 1837 / 2000
#
# --------------Episode:  1837  started----------------
#
# Done in 2 steps
# epoch # 1838 / 2000
#
# --------------Episode:  1838  started----------------
#
# Done in 4 steps
# epoch # 1839 / 2000
#
# --------------Episode:  1839  started----------------
#
# Done in 4 steps
# epoch # 1840 / 2000
#
# --------------Episode:  1840  started----------------
#
# Done in 3 steps
# epoch # 1841 / 2000
#
# --------------Episode:  1841  started----------------
#
# Done in 6 steps
# epoch # 1842 / 2000
#
# --------------Episode:  1842  started----------------
#
# Done in 3 steps
# epoch # 1843 / 2000
#
# --------------Episode:  1843  started----------------
#
# Done in 5 steps
# epoch # 1844 / 2000
#
# --------------Episode:  1844  started----------------
#
# Done in 2 steps
# epoch # 1845 / 2000
#
# --------------Episode:  1845  started----------------
#
# Done in 5 steps
# epoch # 1846 / 2000
#
# --------------Episode:  1846  started----------------
#
# Done in 6 steps
# epoch # 1847 / 2000
#
# --------------Episode:  1847  started----------------
#
# Done in 2 steps
# epoch # 1848 / 2000
#
# --------------Episode:  1848  started----------------
#
# Done in 4 steps
# epoch # 1849 / 2000
#
# --------------Episode:  1849  started----------------
#
# Done in 6 steps
# epoch # 1850 / 2000
#
# --------------Episode:  1850  started----------------
#
# Done in 4 steps
# epoch # 1851 / 2000
#
# --------------Episode:  1851  started----------------
#
# Done in 6 steps
# epoch # 1852 / 2000
#
# --------------Episode:  1852  started----------------
#
# Done in 5 steps
# epoch # 1853 / 2000
#
# --------------Episode:  1853  started----------------
#
# Done in 2 steps
# epoch # 1854 / 2000
#
# --------------Episode:  1854  started----------------
#
# Done in 6 steps
# epoch # 1855 / 2000
#
# --------------Episode:  1855  started----------------
#
# Done in 5 steps
# epoch # 1856 / 2000
#
# --------------Episode:  1856  started----------------
#
# Done in 4 steps
# epoch # 1857 / 2000
#
# --------------Episode:  1857  started----------------
#
# Done in 4 steps
# epoch # 1858 / 2000
#
# --------------Episode:  1858  started----------------
#
# Done in 8 steps
# epoch # 1859 / 2000
#
# --------------Episode:  1859  started----------------
#
# Done in 5 steps
# epoch # 1860 / 2000
#
# --------------Episode:  1860  started----------------
#
# Done in 4 steps
# epoch # 1861 / 2000
#
# --------------Episode:  1861  started----------------
#
# Done in 4 steps
# epoch # 1862 / 2000
#
# --------------Episode:  1862  started----------------
#
# Done in 6 steps
# epoch # 1863 / 2000
#
# --------------Episode:  1863  started----------------
#
# Done in 7 steps
# epoch # 1864 / 2000
#
# --------------Episode:  1864  started----------------
#
# Done in 2 steps
# epoch # 1865 / 2000
#
# --------------Episode:  1865  started----------------
#
# Done in 5 steps
# epoch # 1866 / 2000
#
# --------------Episode:  1866  started----------------
#
# Done in 6 steps
# epoch # 1867 / 2000
#
# --------------Episode:  1867  started----------------
#
# Done in 6 steps
# epoch # 1868 / 2000
#
# --------------Episode:  1868  started----------------
#
# Done in 4 steps
# epoch # 1869 / 2000
#
# --------------Episode:  1869  started----------------
#
# Done in 3 steps
# epoch # 1870 / 2000
#
# --------------Episode:  1870  started----------------
#
# Done in 5 steps
# epoch # 1871 / 2000
#
# --------------Episode:  1871  started----------------
#
# Done in 4 steps
# epoch # 1872 / 2000
#
# --------------Episode:  1872  started----------------
#
# Done in 6 steps
# epoch # 1873 / 2000
#
# --------------Episode:  1873  started----------------
#
# Done in 6 steps
# epoch # 1874 / 2000
#
# --------------Episode:  1874  started----------------
#
# Done in 5 steps
# epoch # 1875 / 2000
#
# --------------Episode:  1875  started----------------
#
# Done in 4 steps
# epoch # 1876 / 2000
#
# --------------Episode:  1876  started----------------
#
# Done in 2 steps
# epoch # 1877 / 2000
#
# --------------Episode:  1877  started----------------
#
# Done in 7 steps
# epoch # 1878 / 2000
#
# --------------Episode:  1878  started----------------
#
# Done in 8 steps
# epoch # 1879 / 2000
#
# --------------Episode:  1879  started----------------
#
# Done in 5 steps
# epoch # 1880 / 2000
#
# --------------Episode:  1880  started----------------
#
# Done in 7 steps
# epoch # 1881 / 2000
#
# --------------Episode:  1881  started----------------
#
# Done in 8 steps
# epoch # 1882 / 2000
#
# --------------Episode:  1882  started----------------
#
# Done in 5 steps
# epoch # 1883 / 2000
#
# --------------Episode:  1883  started----------------
#
# Done in 6 steps
# epoch # 1884 / 2000
#
# --------------Episode:  1884  started----------------
#
# Done in 5 steps
# epoch # 1885 / 2000
#
# --------------Episode:  1885  started----------------
#
# Done in 3 steps
# epoch # 1886 / 2000
#
# --------------Episode:  1886  started----------------
#
# Done in 3 steps
# epoch # 1887 / 2000
#
# --------------Episode:  1887  started----------------
#
# Done in 3 steps
# epoch # 1888 / 2000
#
# --------------Episode:  1888  started----------------
#
# Done in 7 steps
# epoch # 1889 / 2000
#
# --------------Episode:  1889  started----------------
#
# Done in 4 steps
# epoch # 1890 / 2000
#
# --------------Episode:  1890  started----------------
#
# Done in 8 steps
# epoch # 1891 / 2000
#
# --------------Episode:  1891  started----------------
#
# Done in 5 steps
# epoch # 1892 / 2000
#
# --------------Episode:  1892  started----------------
#
# Done in 3 steps
# epoch # 1893 / 2000
#
# --------------Episode:  1893  started----------------
#
# Done in 4 steps
# epoch # 1894 / 2000
#
# --------------Episode:  1894  started----------------
#
# Done in 5 steps
# epoch # 1895 / 2000
#
# --------------Episode:  1895  started----------------
#
# Done in 5 steps
# epoch # 1896 / 2000
#
# --------------Episode:  1896  started----------------
#
# Done in 7 steps
# epoch # 1897 / 2000
#
# --------------Episode:  1897  started----------------
#
# Done in 5 steps
# epoch # 1898 / 2000
#
# --------------Episode:  1898  started----------------
#
# Done in 7 steps
# epoch # 1899 / 2000
#
# --------------Episode:  1899  started----------------
#
# Done in 5 steps
# epoch # 1900 / 2000
#
# --------------Episode:  1900  started----------------
#
# Done in 7 steps
# epoch # 1901 / 2000
#
# --------------Episode:  1901  started----------------
#
# Done in 4 steps
# epoch # 1902 / 2000
#
# --------------Episode:  1902  started----------------
#
# Done in 8 steps
# epoch # 1903 / 2000
#
# --------------Episode:  1903  started----------------
#
# Done in 5 steps
# epoch # 1904 / 2000
#
# --------------Episode:  1904  started----------------
#
# Done in 7 steps
# epoch # 1905 / 2000
#
# --------------Episode:  1905  started----------------
#
# Done in 7 steps
# epoch # 1906 / 2000
#
# --------------Episode:  1906  started----------------
#
# Done in 5 steps
# epoch # 1907 / 2000
#
# --------------Episode:  1907  started----------------
#
# Done in 7 steps
# epoch # 1908 / 2000
#
# --------------Episode:  1908  started----------------
#
# Done in 5 steps
# epoch # 1909 / 2000
#
# --------------Episode:  1909  started----------------
#
# Done in 7 steps
# epoch # 1910 / 2000
#
# --------------Episode:  1910  started----------------
#
# Done in 4 steps
# epoch # 1911 / 2000
#
# --------------Episode:  1911  started----------------
#
# Done in 7 steps
# epoch # 1912 / 2000
#
# --------------Episode:  1912  started----------------
#
# Done in 5 steps
# epoch # 1913 / 2000
#
# --------------Episode:  1913  started----------------
#
# Done in 5 steps
# epoch # 1914 / 2000
#
# --------------Episode:  1914  started----------------
#
# Done in 6 steps
# epoch # 1915 / 2000
#
# --------------Episode:  1915  started----------------
#
# Done in 5 steps
# epoch # 1916 / 2000
#
# --------------Episode:  1916  started----------------
#
# Done in 5 steps
# epoch # 1917 / 2000
#
# --------------Episode:  1917  started----------------
#
# Done in 3 steps
# epoch # 1918 / 2000
#
# --------------Episode:  1918  started----------------
#
# Done in 5 steps
# epoch # 1919 / 2000
#
# --------------Episode:  1919  started----------------
#
# Done in 7 steps
# epoch # 1920 / 2000
#
# --------------Episode:  1920  started----------------
#
# Done in 8 steps
# epoch # 1921 / 2000
#
# --------------Episode:  1921  started----------------
#
# Done in 4 steps
# epoch # 1922 / 2000
#
# --------------Episode:  1922  started----------------
#
# Done in 8 steps
# epoch # 1923 / 2000
#
# --------------Episode:  1923  started----------------
#
# Done in 5 steps
# epoch # 1924 / 2000
#
# --------------Episode:  1924  started----------------
#
# Done in 5 steps
# epoch # 1925 / 2000
#
# --------------Episode:  1925  started----------------
#
# Done in 7 steps
# epoch # 1926 / 2000
#
# --------------Episode:  1926  started----------------
#
# Done in 7 steps
# epoch # 1927 / 2000
#
# --------------Episode:  1927  started----------------
#
# Done in 5 steps
# epoch # 1928 / 2000
#
# --------------Episode:  1928  started----------------
#
# Done in 3 steps
# epoch # 1929 / 2000
#
# --------------Episode:  1929  started----------------
#
# Done in 8 steps
# epoch # 1930 / 2000
#
# --------------Episode:  1930  started----------------
#
# Done in 4 steps
# epoch # 1931 / 2000
#
# --------------Episode:  1931  started----------------
#
# Done in 7 steps
# epoch # 1932 / 2000
#
# --------------Episode:  1932  started----------------
#
# Done in 3 steps
# epoch # 1933 / 2000
#
# --------------Episode:  1933  started----------------
#
# Done in 5 steps
# epoch # 1934 / 2000
#
# --------------Episode:  1934  started----------------
#
# Done in 4 steps
# epoch # 1935 / 2000
#
# --------------Episode:  1935  started----------------
#
# Done in 3 steps
# epoch # 1936 / 2000
#
# --------------Episode:  1936  started----------------
#
# Done in 4 steps
# epoch # 1937 / 2000
#
# --------------Episode:  1937  started----------------
#
# Done in 6 steps
# epoch # 1938 / 2000
#
# --------------Episode:  1938  started----------------
#
# Done in 5 steps
# epoch # 1939 / 2000
#
# --------------Episode:  1939  started----------------
#
# Done in 2 steps
# epoch # 1940 / 2000
#
# --------------Episode:  1940  started----------------
#
# Done in 7 steps
# epoch # 1941 / 2000
#
# --------------Episode:  1941  started----------------
#
# Done in 4 steps
# epoch # 1942 / 2000
#
# --------------Episode:  1942  started----------------
#
# Done in 6 steps
# epoch # 1943 / 2000
#
# --------------Episode:  1943  started----------------
#
# Done in 6 steps
# epoch # 1944 / 2000
#
# --------------Episode:  1944  started----------------
#
# Done in 7 steps
# epoch # 1945 / 2000
#
# --------------Episode:  1945  started----------------
#
# Done in 5 steps
# epoch # 1946 / 2000
#
# --------------Episode:  1946  started----------------
#
# Done in 8 steps
# epoch # 1947 / 2000
#
# --------------Episode:  1947  started----------------
#
# Done in 3 steps
# epoch # 1948 / 2000
#
# --------------Episode:  1948  started----------------
#
# Done in 4 steps
# epoch # 1949 / 2000
#
# --------------Episode:  1949  started----------------
#
# Done in 7 steps
# epoch # 1950 / 2000
#
# --------------Episode:  1950  started----------------
#
# Done in 2 steps
# epoch # 1951 / 2000
#
# --------------Episode:  1951  started----------------
#
# Done in 7 steps
# epoch # 1952 / 2000
#
# --------------Episode:  1952  started----------------
#
# Done in 6 steps
# epoch # 1953 / 2000
#
# --------------Episode:  1953  started----------------
#
# Done in 3 steps
# epoch # 1954 / 2000
#
# --------------Episode:  1954  started----------------
#
# Done in 5 steps
# epoch # 1955 / 2000
#
# --------------Episode:  1955  started----------------
#
# Done in 6 steps
# epoch # 1956 / 2000
#
# --------------Episode:  1956  started----------------
#
# Done in 7 steps
# epoch # 1957 / 2000
#
# --------------Episode:  1957  started----------------
#
# Done in 6 steps
# epoch # 1958 / 2000
#
# --------------Episode:  1958  started----------------
#
# Done in 5 steps
# epoch # 1959 / 2000
#
# --------------Episode:  1959  started----------------
#
# Done in 2 steps
# epoch # 1960 / 2000
#
# --------------Episode:  1960  started----------------
#
# Done in 3 steps
# epoch # 1961 / 2000
#
# --------------Episode:  1961  started----------------
#
# Done in 5 steps
# epoch # 1962 / 2000
#
# --------------Episode:  1962  started----------------
#
# Done in 5 steps
# epoch # 1963 / 2000
#
# --------------Episode:  1963  started----------------
#
# Done in 2 steps
# epoch # 1964 / 2000
#
# --------------Episode:  1964  started----------------
#
# Done in 6 steps
# epoch # 1965 / 2000
#
# --------------Episode:  1965  started----------------
#
# Done in 2 steps
# epoch # 1966 / 2000
#
# --------------Episode:  1966  started----------------
#
# Done in 7 steps
# epoch # 1967 / 2000
#
# --------------Episode:  1967  started----------------
#
# Done in 3 steps
# epoch # 1968 / 2000
#
# --------------Episode:  1968  started----------------
#
# Done in 7 steps
# epoch # 1969 / 2000
#
# --------------Episode:  1969  started----------------
#
# Done in 7 steps
# epoch # 1970 / 2000
#
# --------------Episode:  1970  started----------------
#
# Done in 3 steps
# epoch # 1971 / 2000
#
# --------------Episode:  1971  started----------------
#
# Done in 2 steps
# epoch # 1972 / 2000
#
# --------------Episode:  1972  started----------------
#
# Done in 7 steps
# epoch # 1973 / 2000
#
# --------------Episode:  1973  started----------------
#
# Done in 7 steps
# epoch # 1974 / 2000
#
# --------------Episode:  1974  started----------------
#
# Done in 6 steps
# epoch # 1975 / 2000
#
# --------------Episode:  1975  started----------------
#
# Done in 7 steps
# epoch # 1976 / 2000
#
# --------------Episode:  1976  started----------------
#
# Done in 5 steps
# epoch # 1977 / 2000
#
# --------------Episode:  1977  started----------------
#
# Done in 4 steps
# epoch # 1978 / 2000
#
# --------------Episode:  1978  started----------------
#
# Done in 5 steps
# epoch # 1979 / 2000
#
# --------------Episode:  1979  started----------------
#
# Done in 5 steps
# epoch # 1980 / 2000
#
# --------------Episode:  1980  started----------------
#
# Done in 6 steps
# epoch # 1981 / 2000
#
# --------------Episode:  1981  started----------------
#
# Done in 3 steps
# epoch # 1982 / 2000
#
# --------------Episode:  1982  started----------------
#
# Done in 6 steps
# epoch # 1983 / 2000
#
# --------------Episode:  1983  started----------------
#
# Done in 4 steps
# epoch # 1984 / 2000
#
# --------------Episode:  1984  started----------------
#
# Done in 5 steps
# epoch # 1985 / 2000
#
# --------------Episode:  1985  started----------------
#
# Done in 6 steps
# epoch # 1986 / 2000
#
# --------------Episode:  1986  started----------------
#
# Done in 6 steps
# epoch # 1987 / 2000
#
# --------------Episode:  1987  started----------------
#
# Done in 7 steps
# epoch # 1988 / 2000
#
# --------------Episode:  1988  started----------------
#
# Done in 7 steps
# epoch # 1989 / 2000
#
# --------------Episode:  1989  started----------------
#
# Done in 6 steps
# epoch # 1990 / 2000
#
# --------------Episode:  1990  started----------------
#
# Done in 6 steps
# epoch # 1991 / 2000
#
# --------------Episode:  1991  started----------------
#
# Done in 6 steps
# epoch # 1992 / 2000
#
# --------------Episode:  1992  started----------------
#
# Done in 5 steps
# epoch # 1993 / 2000
#
# --------------Episode:  1993  started----------------
#
# Done in 4 steps
# epoch # 1994 / 2000
#
# --------------Episode:  1994  started----------------
#
# Done in 5 steps
# epoch # 1995 / 2000
#
# --------------Episode:  1995  started----------------
#
# Done in 2 steps
# epoch # 1996 / 2000
#
# --------------Episode:  1996  started----------------
#
# Done in 5 steps
# epoch # 1997 / 2000
#
# --------------Episode:  1997  started----------------
#
# Done in 5 steps
# epoch # 1998 / 2000
#
# --------------Episode:  1998  started----------------
#
# Done in 3 steps
# epoch # 1999 / 2000
#
# --------------Episode:  1999  started----------------
#
# Done in 3 steps
# epoch # 2000 / 2000
#
# --------------Episode:  2000  started----------------
#
# Done in 5 steps
# Total Time taken:  144.80585980415344
